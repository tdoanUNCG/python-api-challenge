# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/hw_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(weather_api_key)
# cities
# number of batches to run
print(len(cities))
num_of_batches = len(cities)/50
left_over = (len(cities)%50)
print(int(num_of_batches))
print(left_over)
# Out:
# 603
# 12
# 3

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it's
# being processed (with the city number and city name).
url = "http://api.openweathermap.org/data/2.5/weather?"
#city = "new norfolk"
# build query URL
#query_url = url + "appid=" + weather_api_key + "&q=" + city
# print(query_url)
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
ow_cities = []

# %%
print(f"Beginning Data Retrieval\n-----------------------------")
for city in cities:
    # build query URL
    query_url = url + 'appid=' + weather_api_key + '&q=' + city
    # print(query_url)
    response = requests.get(query_url).json()
    if response['cod'] == '404':
        print(f"{response['message']}. Skipping...")
    else:
        print(f"Processing... | {city}")
        ow_cities.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
    time.sleep(0.2)

# convert k to f in max_temp list
for i in range(len(max_temp)):
    max_temp[i] = (max_temp[i]-273.15)*(9/5)+32

# convert wind speed to mph
for j in range(len(wind_speed)):
    wind_speed[j] = wind_speed[j]*2.237
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing... | lompoc
# Processing... | mahebourg
# Processing... | chichli
# Processing... | porto-vecchio
# Processing... | yumen
# Processing... | college
# Processing... | chuy
# Processing... | socastee
# Processing... | port alfred
# Processing... | cidreira
# Processing... | narsaq
# Processing... | souillac
# Processing... | punta arenas
# Processing... | dryden
# Processing... | biltine
# Processing... | wanning
# Processing... | hilo
# Processing... | atuona
# Processing... | barrow
# Processing... | kruisfontein
# Processing... | cagliliog
# Processing... | mataura
# Processing... | nikolskoye
# Processing... | tuktoyaktuk
# Processing... | saryozek
# Processing... | qaanaaq
# Processing... | albany
# city not found. Skipping...
# Processing... | lebu
# Processing... | busselton
# Processing... | marawi
# Processing... | san patricio
# Processing... | saskylakh
# Processing... | bubaque
# Processing... | olafsvik
# Processing... | castro
# Processing... | san quintin
# Processing... | hearst
# Processing... | iberia
# Processing... | esperance
# Processing... | fortuna
# Processing... | komsomolskiy
# Processing... | kattivakkam
# Processing... | butaritari
# Processing... | cape town
# Processing... | hobart
# Processing... | hermanus
# Processing... | ilulissat
# Processing... | geraldton
# Processing... | dikson
# city not found. Skipping...
# city not found. Skipping...
# Processing... | kaitangata
# Processing... | krasnoarmeyskoye
# Processing... | bluff
# city not found. Skipping...
# Processing... | bethel
# Processing... | cabo san lucas
# Processing... | waipawa
# Processing... | reshetylivka
# Processing... | ancud
# Processing... | lavrentiya
# Processing... | hohhot
# Processing... | guerrero negro
# Processing... | chokurdakh
# Processing... | ushuaia
# Processing... | lieksa
# Processing... | kavieng
# Processing... | severo-kurilsk
# Processing... | norman wells
# Processing... | limoux
# Processing... | sirjan
# Processing... | portland
# Processing... | rikitea
# Processing... | prince rupert
# Processing... | elat
# Processing... | sorland
# Processing... | mar del plata
# Processing... | port-gentil
# Processing... | jamestown
# Processing... | hambantota
# Processing... | bredasdorp
# city not found. Skipping...
# Processing... | camopi
# Processing... | kiruna
# Processing... | havre-saint-pierre
# Processing... | poum
# Processing... | port elizabeth
# Processing... | iqaluit
# Processing... | noumea
# city not found. Skipping...
# Processing... | hovd
# Processing... | klaksvik
# Processing... | cayenne
# Processing... | bilibino
# Processing... | ixtapa
# Processing... | peace river
# Processing... | vadso
# Processing... | east london
# Processing... | mitu
# Processing... | constitucion
# Processing... | nizhnevartovsk
# Processing... | kropotkin
# Processing... | deniliquin
# Processing... | bure
# Processing... | vaini
# Processing... | touros
# Processing... | dzhebariki-khaya
# Processing... | kudahuvadhoo
# Processing... | arraial do cabo
# city not found. Skipping...
# Processing... | vila velha
# Processing... | ponta do sol
# Processing... | thompson
# Processing... | flinders
# Processing... | comodoro rivadavia
# Processing... | ilo
# Processing... | muscat
# Processing... | jepelacio
# Processing... | pujili
# Processing... | samoylovka
# Processing... | lewiston
# Processing... | kulhudhuffushi
# Processing... | georgetown
# Processing... | vestmannaeyjar
# Processing... | puerto del rosario
# Processing... | khatanga
# Processing... | new norfolk
# Processing... | saldanha
# Processing... | apatity
# Processing... | leningradskiy
# Processing... | kapaa
# Processing... | saint-philippe
# Processing... | namatanai
# Processing... | yulara
# city not found. Skipping...
# Processing... | deep river
# Processing... | hay river
# Processing... | puerto ayora
# Processing... | tautira
# city not found. Skipping...
# Processing... | bengkulu
# city not found. Skipping...
# city not found. Skipping...
# Processing... | avarua
# Processing... | whitehorse
# Processing... | sitka
# Processing... | carnarvon
# Processing... | taltal
# Processing... | honningsvag
# Processing... | sandwick
# Processing... | arroyo
# Processing... | rio gallegos
# Processing... | kosh-agach
# Processing... | namibe
# Processing... | high level
# city not found. Skipping...
# Processing... | katsuura
# Processing... | cherskiy
# Processing... | bitung
# Processing... | yellowknife
# city not found. Skipping...
# Processing... | north bend
# Processing... | matagami
# city not found. Skipping...
# Processing... | high rock
# Processing... | tasiilaq
# Processing... | pushkinskiye gory
# Processing... | panaba
# Processing... | kalmunai
# Processing... | manali
# Processing... | padang
# Processing... | airai
# Processing... | polewali
# Processing... | karratha
# Processing... | skibbereen
# city not found. Skipping...
# Processing... | bardiyah
# Processing... | naze
# Processing... | kyra
# Processing... | inirida
# Processing... | bambous virieux
# city not found. Skipping...
# Processing... | paamiut
# Processing... | inuvik
# Processing... | amapa
# Processing... | victoria
# Processing... | ambunti
# city not found. Skipping...
# Processing... | malokaterynivka
# Processing... | molodizhne
# Processing... | faanui
# Processing... | riverton
# Processing... | asau
# Processing... | isangel
# Processing... | port hardy
# Processing... | mustafakemalpasa
# Processing... | pimenta bueno
# Processing... | laguna
# Processing... | kavaratti
# Processing... | alamosa
# Processing... | brunehaut
# Processing... | iguatu
# Processing... | beloha
# Processing... | wanaka
# Processing... | sailana
# Processing... | sao filipe
# Processing... | otanche
# city not found. Skipping...
# Processing... | the valley
# Processing... | iquitos
# Processing... | makakilo city
# Processing... | pangkalanbuun
# Processing... | ribeira grande
# Processing... | sao felix do xingu
# Processing... | umm kaddadah
# city not found. Skipping...
# Processing... | kumbo
# Processing... | kissidougou
# Processing... | hithadhoo
# Processing... | schruns
# Processing... | denpasar
# Processing... | antalaha
# city not found. Skipping...
# Processing... | saint-pierre
# Processing... | melito di porto salvo
# Processing... | ust-omchug
# city not found. Skipping...
# Processing... | kolosovka
# Processing... | appleton
# Processing... | port lavaca
# Processing... | palora
# Processing... | sorong
# Processing... | bayburt
# Processing... | adrar
# Processing... | los llanos de aridane
# Processing... | saint george
# Processing... | nanortalik
# Processing... | berlevag
# Processing... | bambanglipuro
# Processing... | ahipara
# city not found. Skipping...
# Processing... | quatre cocos
# Processing... | coihaique
# Processing... | wanganui
# Processing... | dubbo
# Processing... | luderitz
# city not found. Skipping...
# city not found. Skipping...
# city not found. Skipping...
# Processing... | barentu
# Processing... | pevek
# Processing... | harper
# Processing... | flin flon
# Processing... | provideniya
# city not found. Skipping...
# Processing... | waitati
# Processing... | paracuru
# Processing... | smirnykh
# Processing... | pampa
# Processing... | kommunar
# Processing... | torbay
# Processing... | humberto de campos
# Processing... | bonnyville
# Processing... | villacarrillo
# Processing... | maragogi
# Processing... | buena vista
# Processing... | krasnoselkup
# Processing... | dalvik
# Processing... | krasnoarmeysk
# Processing... | jaggayyapeta
# Processing... | aden
# city not found. Skipping...
# city not found. Skipping...
# Processing... | nuuk
# Processing... | sao joao da barra
# Processing... | teno
# Processing... | okato
# Processing... | istanbul
# Processing... | vaitape
# Processing... | waddan
# Processing... | ghanzi
# Processing... | pala
# Processing... | mount gambier
# city not found. Skipping...
# city not found. Skipping...
# Processing... | presidencia roque saenz pena
# Processing... | santander de quilichao
# Processing... | kaspiysk
# Processing... | kijang
# Processing... | sanchor
# Processing... | deputatskiy
# Processing... | avera
# Processing... | gat
# Processing... | solnechnyy
# Processing... | baturaja
# Processing... | ushibuka
# Processing... | coquimbo
# Processing... | san cristobal
# Processing... | andenes
# Processing... | inongo
# Processing... | maputo
# Processing... | matara
# Processing... | pangnirtung
# Processing... | mooresville
# Processing... | itacoatiara
# Processing... | esmeraldas
# Processing... | lagoa
# Processing... | caravelas
# city not found. Skipping...
# Processing... | havelock
# city not found. Skipping...
# Processing... | ugoofaaru
# Processing... | ostrovnoy
# Processing... | allanridge
# Processing... | nome
# Processing... | novikovo
# Processing... | slave lake
# Processing... | gabu
# Processing... | waingapu
# Processing... | moron
# Processing... | kiama
# Processing... | bahia blanca
# Processing... | birao
# Processing... | bathsheba
# Processing... | sinop
# city not found. Skipping...
# Processing... | port-cartier
# Processing... | dongsheng
# Processing... | seymchan
# Processing... | diego de almagro
# Processing... | veszprem
# city not found. Skipping...
# Processing... | wangqing
# Processing... | totness
# Processing... | narasannapeta
# Processing... | maniitsoq
# Processing... | oskemen
# Processing... | dunedin
# Processing... | rocha
# Processing... | vao
# Processing... | keuruu
# Processing... | beltinci
# Processing... | chemal
# Processing... | tuatapere
# Processing... | sarakhs
# Processing... | husavik
# Processing... | kabinda
# Processing... | warrington
# Processing... | kurumkan
# Processing... | muyezerskiy
# Processing... | asyut
# Processing... | lander
# Processing... | nantucket
# Processing... | chara
# Processing... | lata
# Processing... | dudinka
# Processing... | burnie
# Processing... | upernavik
# Processing... | aketi
# Processing... | idlib
# Processing... | pangai
# Processing... | san andres
# Processing... | altamira
# Processing... | shenyang
# Processing... | gamba
# Processing... | toumodi
# Processing... | tiksi
# Processing... | batasan
# Processing... | sungurlare
# Processing... | clyde river
# Processing... | bontang
# Processing... | lambarene
# Processing... | namtsy
# city not found. Skipping...
# Processing... | aykhal
# Processing... | loandjili
# Processing... | faya
# Processing... | kodiak
# city not found. Skipping...
# Processing... | inhambane
# Processing... | arinos
# Processing... | nishihara
# Processing... | buin
# Processing... | maningrida
# Processing... | longyearbyen
# Processing... | changqing
# Processing... | te anau
# Processing... | umarga
# Processing... | shaoyang
# Processing... | ola
# Processing... | mitsamiouli
# Processing... | edgewater
# Processing... | olinda
# Processing... | port hedland
# Processing... | dakoro
# Processing... | otane
# Processing... | leh
# Processing... | maravatio
# Processing... | guarapari
# Processing... | presidente medici
# Processing... | vila
# Processing... | iralaya
# Processing... | nemuro
# Processing... | sinnamary
# Processing... | qaqortoq
# Processing... | dum duma
# Processing... | seoul
# Processing... | westport
# Processing... | oistins
# Processing... | minbu
# Processing... | henties bay
# Processing... | elizabeth city
# Processing... | katangli
# city not found. Skipping...
# Processing... | alta floresta
# Processing... | kasulu
# Processing... | mangai
# Processing... | leiyang
# Processing... | vila franca do campo
# Processing... | port blair
# Processing... | kahului
# Processing... | winnemucca
# Processing... | yanam
# Processing... | meulaboh
# city not found. Skipping...
# Processing... | taoudenni
# Processing... | andros town
# Processing... | dingle
# Processing... | codigoro
# Processing... | le port
# Processing... | itarema
# Processing... | codrington
# Processing... | watsa
# Processing... | aksu
# Processing... | zhigansk
# Processing... | clovis
# Processing... | ayna
# Processing... | teya
# city not found. Skipping...
# Processing... | abu samrah
# Processing... | marshfield
# Processing... | katol
# city not found. Skipping...
# Processing... | mavrovi anovi
# Processing... | mount isa
# Processing... | lorengau
# Processing... | ciudad guayana
# Processing... | aykino
# Processing... | luebo
# Processing... | nouadhibou
# Processing... | hasaki
# Processing... | tacna
# Processing... | ikom
# Processing... | klyuchi
# Processing... | la peca
# Processing... | khash
# Processing... | saint anthony
# Processing... | roma
# Processing... | aragats
# Processing... | oranjestad
# Processing... | alice springs
# Processing... | talnakh
# Processing... | la ronge
# Processing... | ketchikan
# Processing... | hamilton
# Processing... | huaibei
# Processing... | roald
# Processing... | grindavik
# Processing... | pryazha
# Processing... | ulaanbaatar
# Processing... | severnyy
# Processing... | bani
# Processing... | stokmarknes
# Processing... | batemans bay
# Processing... | poso
# Processing... | terrace
# Processing... | iranduba
# Processing... | sambava
# city not found. Skipping...
# Processing... | rawson
# Processing... | yar-sale
# Processing... | coos bay
# Processing... | muros
# Processing... | biak
# Processing... | denizli
# Processing... | kinna
# Processing... | reconquista
# Processing... | balkanabat
# Processing... | jamsa
# Processing... | mehamn
# Processing... | miranda
# Processing... | jalingo
# Processing... | coahuayana
# Processing... | changji
# Processing... | fairbanks
# Processing... | laurel
# Processing... | knysna
# Processing... | boyolangu
# Processing... | upata
# Processing... | caranavi
# Processing... | lasa
# Processing... | bastia
# Processing... | conselheiro lafaiete
# Processing... | urbano santos
# Processing... | san lorenzo
# Processing... | linjiang
# Processing... | salta
# Processing... | merano
# Processing... | santa catarina de tepehuanes
# Processing... | labuhan
# Processing... | weligama
# Processing... | beian
# Processing... | naberera
# Processing... | billings
# Processing... | gornopravdinsk
# Processing... | terrasini
# Processing... | brandon
# Processing... | simplicio mendes
# Processing... | puerto baquerizo moreno
# Processing... | atikokan
# Processing... | honiara
# Processing... | santa cruz
# Processing... | samarai
# Processing... | saint-jovite
# Processing... | warren
# Processing... | niltepec
# Processing... | giehun
# Processing... | acarau
# Processing... | deoband
# Processing... | calafell
# Processing... | izumo
# Processing... | korla
# Processing... | vredendal
# Processing... | luau
# Processing... | yatou
# Processing... | kununurra
# Processing... | port lincoln
# Processing... | banjar
# Processing... | chulman
# Processing... | casa nova
# Processing... | usinsk
# Processing... | emerald
# Processing... | najran
# Processing... | pitimbu
# Processing... | kondopoga
# Processing... | tomatlan
# Processing... | pringsewu
# Processing... | poprad
# Processing... | qinzhou
# Processing... | riviere-au-renard
# Processing... | san vicente
# Processing... | south sioux city
# Processing... | mapiripan
# Processing... | arosa
# Processing... | pabianice
# Processing... | bayonet point
# city not found. Skipping...
# Processing... | kysyl-syr
# Processing... | newport
# Processing... | coffs harbour
# Processing... | mackay
# Processing... | singkawang
# Processing... | san roque
# Processing... | yarada
# Processing... | yabelo
# city not found. Skipping...
# Processing... | liverpool
# Processing... | springbok
# Processing... | port hawkesbury
# Processing... | sarab
# Processing... | mayumba
# Processing... | malakal
# Processing... | lazaro cardenas
# city not found. Skipping...
# Processing... | conakry
# Processing... | charters towers
# Processing... | farafangana
# Processing... | omsukchan
# Processing... | belozerskoye
# Processing... | tarakan
# Processing... | methoni
# Processing... | shimanovsk
# Processing... | kerewan
# Processing... | alakurtti
# Processing... | jutai
# Processing... | axim
# Processing... | behbahan
# Processing... | hobyo
# Processing... | mae hong son
# Processing... | puerto colombia
# Processing... | manuk mangkaw
# Processing... | marienburg
# Processing... | martapura
# Processing... | irbit
# Processing... | viedma
# Processing... | marsa matruh
# city not found. Skipping...
# Processing... | raymondville
# Processing... | ngawen
# Processing... | gold coast
# Processing... | xinyu
# Processing... | half moon bay

# %%
weather_dict = {
    "City": ow_cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
ow_weather_df = pd.DataFrame(weather_dict)
ow_weather_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Lompoc           1      US  1579922377        87  34.64 -120.46
# 1        Mahebourg          75      MU  1579922446        88 -20.41   57.70
# 2          Chichli           0      IN  1579922598        42  22.83   78.82
# 3    Porto-Vecchio           0      FR  1579922598        93  41.59    9.28
# 4            Yumen           0      CN  1579922598        54  40.28   97.20
# ..             ...         ...     ...         ...       ...    ...     ...
# 553   Raymondville          75      US  1579923989        72  26.48  -97.78
# 554         Ngawen          38      ID  1579923990        73  -7.00  111.31
# 555     Gold Coast          75      AU  1579923863        74 -28.00  153.43
# 556          Xinyu         100      CN  1579923990        92  27.80  114.93
# 557  Half Moon Bay          75      US  1579923991        93  37.46 -122.43
#
#      Max Temp  Wind Speed
# 0      62.006    10.29020
# 1      80.600    19.46190
# 2      58.766     3.28839
# 3      51.800     8.05320
# 4      22.064    11.40870
# ..        ...         ...
# 553    64.994     3.35550
# 554    85.010     2.12515
# 555    86.000    11.40870
# 556    45.734     7.56106
# 557    59.000     3.35550
#
# [558 rows x 9 columns]

# %%
ow_weather_df.to_csv('ow_weather_df.csv',index=False)
# plot latitude vs temperature
lat_x = weather_dict['Lat']
temp_y = weather_dict['Max Temp']
plt.scatter(lat_x,temp_y,alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.show()
plt.savefig('lat_vs_temp.png')

# %%
# plot latitude vs humidity
plt.scatter(weather_dict['Lat'],weather_dict['Humidity'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
plt.savefig('lat_vs_humidity.png')

# %%
# plot latitude vs cloudiness
plt.scatter(weather_dict['Lat'],weather_dict['Cloudiness'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
plt.savefig('lat_vs_cloudiness.png')

# %%
# plot latitude vs wind speed
plt.scatter(weather_dict['Lat'],weather_dict['Wind Speed'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
plt.savefig('lat_vs_wind_speed.png')

# %%
# isolate northern and southern hemisphere cities
northern_hem = []
southern_hem = []
northern_hem_cities = []
southern_hem_cities = []
northern_hem_temp = []
southern_hem_temp = []
northern_hem_hum = []
southern_hem_hum = []
northern_hem_cloud = []
southern_hem_cloud = []
northern_hem_wind = []
southern_hem_wind = []
for m in range(len(longitude)):
    if longitude[m] > 0:
        northern_hem.append(longitude[m])
        northern_hem_cities.append(ow_cities[m])
        northern_hem_temp.append(max_temp[m])
        northern_hem_hum.append(humidity[m])
        northern_hem_cloud.append(cloudiness[m])
        northern_hem_wind.append(wind_speed[m])
    else:
        southern_hem.append(longitude[m])
        southern_hem_cities.append(ow_cities[m])
        southern_hem_temp.append(max_temp[m])
        southern_hem_hum.append(humidity[m])
        southern_hem_cloud.append(cloudiness[m])
        southern_hem_wind.append(wind_speed[m])

# %%
#northern_hem
northern = {
    "City": northern_hem_cities,
    "Lat": northern_hem,
    "Max Temp": northern_hem_temp,
    "Humidity": northern_hem_hum,
    "Cloudiness": northern_hem_cloud,
    "Wind Speed": northern_hem_wind
}
north_df = pd.DataFrame(northern)

# southern hem
southern = {
    "City": southern_hem_cities,
    "Lat": southern_hem,
    "Max Temp": southern_hem_temp,
    "Humidity": southern_hem_hum,
    "Cloudiness": southern_hem_cloud,
    "Wind Speed": southern_hem_wind
}
south_df = pd.DataFrame(southern)

# plot northern hem lat vs temp
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Max Temp'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Max Temp'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temp')
ax.set_title('Latitude vs. Temperature')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.06229249883934418

# %%
# plot southern hem lat vs temp
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Max Temp'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Max Temp'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,25),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temp')
ax.set_title('Latitude vs. Temperature')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.20488740555093107

# %%
# plot northern hem lat vs humidity
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Humidity'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Humidity'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('Latitude vs. Humidity')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: -0.13252211733388108

# %%
# plot southern hem lat vs humidity
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Humidity'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Humidity'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('Latitude vs. Humidity')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: -0.004191191111897661

# %%
# plot northern hem lat vs cloudiness
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Cloudiness'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Cloudiness'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.set_title('Latitude vs. Cloudiness')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.056981489397434214

# %%
# plot southern hem lat vs cloudiness
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Cloudiness'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Cloudiness'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.set_title('Latitude vs. Cloudiness')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.09734346074475668

# %%
# plot northern hem lat vs wind speed
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Wind Speed'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Wind Speed'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.set_title('Latitude vs. Wind Speed')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.09845065634935209

# %%
# plot southern hem lat vs wind speed
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Wind Speed'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Wind Speed'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.set_title('Latitude vs. Wind Speed')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.12071407274123967
