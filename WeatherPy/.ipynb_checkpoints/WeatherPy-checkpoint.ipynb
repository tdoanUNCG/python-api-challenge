# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/hw_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(weather_api_key)
# cities
# number of batches to run
print(len(cities))
num_of_batches = len(cities)/50
left_over = (len(cities)%50)
print(int(num_of_batches))
print(left_over)
# Out:
# 622
# 12
# 22

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it's
# being processed (with the city number and city name).
url = "http://api.openweathermap.org/data/2.5/weather?"
#city = "new norfolk"
# build query URL
#query_url = url + "appid=" + weather_api_key + "&q=" + city
# print(query_url)
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
ow_cities = []

# %%
print(f"Beginning Data Retrieval\n-----------------------------")
for city in cities:
    # build query URL
    query_url = url + 'appid=' + weather_api_key + '&q=' + city
    # print(query_url)
    response = requests.get(query_url).json()
    if response['cod'] == '404':
        print(f"{response['message']}. Skipping...")
    else:
        print(f"Processing... | {city}")
        ow_cities.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
    time.sleep(0.2)

# convert k to f in max_temp list
for i in range(len(max_temp)):
    max_temp[i] = (max_temp[i]-273.15)*(9/5)+32

# convert wind speed to mph
for j in range(len(wind_speed)):
    wind_speed[j] = wind_speed[j]*2.237
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing... | lebu
# Processing... | yellowknife
# Processing... | bluff
# city not found. Skipping...
# Processing... | mar del plata
# Processing... | aykhal
# Processing... | blackwater
# Processing... | esperance
# city not found. Skipping...
# Processing... | atuona
# Processing... | hilo
# Processing... | chuy
# Processing... | saint-philippe
# Processing... | port elizabeth
# Processing... | upernavik
# Processing... | pavlogradka
# Processing... | dikson
# Processing... | hanzhong
# Processing... | tasiilaq
# Processing... | arlit
# Processing... | kendari
# Processing... | avarua
# Processing... | vanimo
# Processing... | victoria
# Processing... | baykit
# Processing... | magadan
# Processing... | punta arenas
# Processing... | hermanus
# Processing... | umm kaddadah
# Processing... | panzhihua
# Processing... | pacific grove
# Processing... | darnah
# Processing... | tra vinh
# Processing... | sorland
# Processing... | muroto
# Processing... | belmonte
# Processing... | cherskiy
# Processing... | bima
# Processing... | kruisfontein
# Processing... | barrow
# Processing... | kuala lipis
# Processing... | port blair
# Processing... | sioux lookout
# Processing... | new norfolk
# Processing... | albany
# city not found. Skipping...
# Processing... | novovarshavka
# Processing... | alofi
# Processing... | botwood
# Processing... | jamestown
# Processing... | bengkulu
# Processing... | norman wells
# Processing... | vaini
# Processing... | fond du lac
# Processing... | busselton
# Processing... | krasnoturansk
# city not found. Skipping...
# Processing... | ribeira grande
# Processing... | erenhot
# Processing... | paamiut
# city not found. Skipping...
# Processing... | puerto ayora
# Processing... | chokurdakh
# Processing... | marzuq
# Processing... | kirakira
# Processing... | ostersund
# Processing... | caldwell
# Processing... | hamilton
# Processing... | gigmoto
# Processing... | cape town
# Processing... | mataura
# Processing... | korla
# Processing... | qazvin
# Processing... | olinda
# Processing... | ushuaia
# Processing... | rikitea
# Processing... | kaitangata
# Processing... | ilo
# Processing... | lyngseidet
# Processing... | alberton
# Processing... | caravelas
# Processing... | kantunil
# city not found. Skipping...
# Processing... | kokopo
# Processing... | ponta do sol
# Processing... | aloleng
# Processing... | saskylakh
# Processing... | westport
# Processing... | tabas
# city not found. Skipping...
# Processing... | torbay
# Processing... | mahebourg
# Processing... | sao joao da barra
# Processing... | cabo san lucas
# Processing... | yushala
# Processing... | lubango
# Processing... | butaritari
# Processing... | longyearbyen
# Processing... | lorengau
# Processing... | gunnedah
# Processing... | hasaki
# Processing... | shizuishan
# Processing... | houma
# Processing... | fairmont
# Processing... | vilhena
# Processing... | pevek
# Processing... | arraial do cabo
# city not found. Skipping...
# Processing... | nanortalik
# Processing... | port lincoln
# Processing... | maceio
# city not found. Skipping...
# city not found. Skipping...
# Processing... | olawa
# city not found. Skipping...
# Processing... | ulladulla
# Processing... | mana
# Processing... | narsaq
# Processing... | kavaratti
# Processing... | knysna
# Processing... | yafran
# Processing... | pahrump
# Processing... | jacareacanga
# Processing... | grand gaube
# Processing... | fortuna
# city not found. Skipping...
# Processing... | ano mera
# Processing... | castro
# Processing... | isangel
# Processing... | faanui
# Processing... | kapaa
# Processing... | mujiayingzi
# Processing... | gabi
# Processing... | bukachacha
# Processing... | berlevag
# Processing... | adrar
# Processing... | hokitika
# Processing... | nikolskoye
# Processing... | hobart
# Processing... | tautira
# Processing... | conde
# Processing... | kulhudhuffushi
# Processing... | whitehorse
# Processing... | bambous virieux
# city not found. Skipping...
# Processing... | samarai
# Processing... | svetlogorsk
# Processing... | bosobolo
# city not found. Skipping...
# Processing... | hithadhoo
# Processing... | tiarei
# Processing... | wukari
# Processing... | adre
# Processing... | iqaluit
# Processing... | riyadh
# Processing... | changping
# Processing... | urucui
# Processing... | saldanha
# city not found. Skipping...
# Processing... | aleksandrov gay
# Processing... | boddam
# Processing... | garissa
# Processing... | yumen
# Processing... | bredasdorp
# city not found. Skipping...
# Processing... | souillac
# Processing... | qaanaaq
# Processing... | kankon
# Processing... | chimore
# Processing... | saint anthony
# Processing... | khatanga
# Processing... | usinsk
# Processing... | dunedin
# Processing... | nome
# Processing... | northam
# Processing... | airai
# Processing... | lagoa
# Processing... | rocha
# Processing... | yevlax
# Processing... | saint-leu
# Processing... | saint george
# Processing... | east london
# Processing... | ongandjera
# Processing... | omsukchan
# Processing... | tromso
# Processing... | mweka
# Processing... | clyde river
# city not found. Skipping...
# Processing... | ostrovnoy
# Processing... | half moon bay
# Processing... | ilulissat
# Processing... | hwange
# Processing... | mehamn
# Processing... | talcahuano
# Processing... | port alfred
# city not found. Skipping...
# Processing... | sabha
# Processing... | daru
# Processing... | sao filipe
# Processing... | nizwa
# Processing... | bud
# Processing... | tuktoyaktuk
# Processing... | antofagasta
# Processing... | shahr-e kord
# Processing... | xichang
# Processing... | inuvik
# Processing... | sinnamary
# Processing... | valdivia
# Processing... | port hardy
# Processing... | zeya
# Processing... | acapulco
# Processing... | namibe
# Processing... | syedove
# Processing... | marawi
# city not found. Skipping...
# Processing... | zhangjiakou
# Processing... | panjakent
# Processing... | leh
# Processing... | de-kastri
# Processing... | polovinnoye
# Processing... | tanabi
# Processing... | tahoua
# Processing... | issenye
# Processing... | oshawa
# Processing... | benicarlo
# city not found. Skipping...
# Processing... | general roca
# Processing... | vardo
# Processing... | general pico
# Processing... | georgetown
# Processing... | tarbagatay
# Processing... | arua
# Processing... | carnarvon
# Processing... | faya
# city not found. Skipping...
# Processing... | bethel
# Processing... | tocopilla
# Processing... | oum hadjer
# Processing... | thompson
# city not found. Skipping...
# Processing... | tuatapere
# Processing... | sechura
# Processing... | taoudenni
# Processing... | sao raimundo nonato
# Processing... | hay river
# Processing... | lompoc
# Processing... | kamina
# Processing... | shelburne
# Processing... | canaries
# Processing... | puerto penasco
# Processing... | constitucion
# Processing... | lata
# Processing... | eucaliptus
# Processing... | salamiyah
# Processing... | saint-pierre
# Processing... | seryshevo
# Processing... | ostrow mazowiecka
# Processing... | linjiang
# Processing... | kamenka
# Processing... | ialibu
# Processing... | nalut
# Processing... | amahai
# Processing... | funadhoo
# Processing... | kodiak
# Processing... | guerrero negro
# Processing... | brae
# Processing... | kinsale
# Processing... | hanmer springs
# Processing... | hami
# Processing... | tiksi
# city not found. Skipping...
# Processing... | merauke
# Processing... | tilichiki
# Processing... | saint-joseph
# Processing... | neyvo-shaytanskiy
# Processing... | hanna
# Processing... | itaituba
# Processing... | port moresby
# Processing... | dongdu
# Processing... | vitoria da conquista
# Processing... | barra patuca
# Processing... | yanam
# Processing... | namatanai
# Processing... | cidreira
# Processing... | the pas
# Processing... | taicheng
# Processing... | petropavlovsk-kamchatskiy
# Processing... | aksarka
# Processing... | eureka
# Processing... | suntar
# Processing... | coutances
# Processing... | aurillac
# city not found. Skipping...
# Processing... | tikrit
# Processing... | guane
# Processing... | carbonia
# Processing... | provideniya
# Processing... | sumbe
# Processing... | atambua
# Processing... | de aar
# city not found. Skipping...
# Processing... | sola
# Processing... | dar es salaam
# Processing... | sitka
# Processing... | moose factory
# Processing... | leshukonskoye
# Processing... | geraldton
# Processing... | podporozhye
# Processing... | port antonio
# Processing... | orlik
# Processing... | doha
# Processing... | tonj
# Processing... | anadyr
# city not found. Skipping...
# Processing... | nabire
# Processing... | poum
# Processing... | puerto narino
# Processing... | ust-nera
# Processing... | mezen
# Processing... | ailigandi
# Processing... | amarante do maranhao
# Processing... | verkhnevilyuysk
# Processing... | antalaha
# Processing... | sao miguel do araguaia
# Processing... | dzhebariki-khaya
# Processing... | can
# Processing... | disa
# Processing... | manzhouli
# city not found. Skipping...
# city not found. Skipping...
# Processing... | port-gentil
# Processing... | novorudnyy
# Processing... | yining
# Processing... | kavieng
# Processing... | plettenberg bay
# Processing... | miandrivazo
# Processing... | mahajanga
# Processing... | kauhajoki
# Processing... | thai binh
# Processing... | pekalongan
# Processing... | pindwara
# Processing... | barranca
# Processing... | bograd
# Processing... | pitimbu
# Processing... | lokosovo
# Processing... | masuda
# Processing... | pangnirtung
# Processing... | calama
# Processing... | hobyo
# Processing... | harper
# Processing... | motygino
# Processing... | ganzhou
# Processing... | belaya gora
# Processing... | coolum beach
# Processing... | hualmay
# Processing... | coihaique
# city not found. Skipping...
# Processing... | richards bay
# Processing... | melendugno
# Processing... | luderitz
# Processing... | eatonton
# Processing... | haimen
# Processing... | ust-omchug
# city not found. Skipping...
# Processing... | santa rosa
# Processing... | mozarlandia
# Processing... | martapura
# Processing... | talara
# Processing... | contamana
# Processing... | bougouni
# Processing... | haines junction
# Processing... | dingle
# Processing... | jardim
# Processing... | ripky
# Processing... | biak
# Processing... | saint-francois
# Processing... | palu
# Processing... | asau
# Processing... | road town
# Processing... | batagay-alyta
# Processing... | grindavik
# Processing... | rexburg
# Processing... | shingu
# Processing... | victoria point
# Processing... | atocha
# Processing... | bertoua
# Processing... | chikwawa
# Processing... | goreloye
# Processing... | thaton
# Processing... | dutse
# Processing... | roald
# Processing... | kalmunai
# city not found. Skipping...
# Processing... | flin flon
# Processing... | cumberland
# Processing... | kindu
# city not found. Skipping...
# Processing... | hoogeveen
# Processing... | vega de alatorre
# Processing... | portland
# Processing... | kaabong
# Processing... | buala
# Processing... | rafai
# Processing... | durant
# Processing... | luganville
# Processing... | mancio lima
# Processing... | palmer
# Processing... | puerto escondido
# Processing... | chapais
# Processing... | ust-uda
# Processing... | san rafael
# Processing... | semirom
# city not found. Skipping...
# Processing... | kismayo
# Processing... | severnyy
# Processing... | nurobod
# Processing... | kieta
# Processing... | banda aceh
# Processing... | tezu
# Processing... | russell
# Processing... | gao
# Processing... | kungurtug
# Processing... | deputatskiy
# city not found. Skipping...
# Processing... | ahipara
# city not found. Skipping...
# Processing... | severo-kurilsk
# Processing... | lavrentiya
# Processing... | enfield
# Processing... | maragogi
# Processing... | coos bay
# city not found. Skipping...
# Processing... | coyah
# Processing... | hervey bay
# Processing... | la ronge
# Processing... | oussouye
# Processing... | djambala
# Processing... | san cristobal
# Processing... | grants
# Processing... | nizhniy tsasuchey
# Processing... | piacabucu
# Processing... | jibuti
# Processing... | dandong
# Processing... | biloela
# Processing... | zhifang
# city not found. Skipping...
# Processing... | talnakh
# Processing... | vao
# Processing... | coquimbo
# Processing... | teeli
# Processing... | vanavara
# Processing... | port hedland
# Processing... | redcliffe
# Processing... | naze
# city not found. Skipping...
# Processing... | batemans bay
# Processing... | rio gallegos
# Processing... | emborion
# Processing... | stephenville crossing
# Processing... | prince rupert
# Processing... | goundam
# Processing... | puerto del rosario
# Processing... | thinadhoo
# Processing... | sagaing
# Processing... | kortkeros
# Processing... | mehtar lam
# city not found. Skipping...
# Processing... | umtata
# Processing... | pinega
# city not found. Skipping...
# Processing... | belize
# Processing... | avera
# Processing... | sibu
# Processing... | amarpatan
# Processing... | salem
# Processing... | yulara
# Processing... | hirado
# Processing... | kozhva
# city not found. Skipping...
# Processing... | baoro
# Processing... | tomatlan
# Processing... | kovdor
# Processing... | los llanos de aridane
# Processing... | tynda
# Processing... | paddhari
# Processing... | semey
# Processing... | kununurra
# city not found. Skipping...
# Processing... | mareeba
# Processing... | hailar
# Processing... | altos
# Processing... | mocuba
# Processing... | balikpapan
# city not found. Skipping...
# Processing... | ilhabela
# Processing... | kamiiso
# Processing... | san luis
# Processing... | delvine
# Processing... | dwarka
# Processing... | san quintin
# Processing... | tamandare
# Processing... | labuhan
# Processing... | codrington
# Processing... | marsaxlokk
# Processing... | paraguacu paulista
# city not found. Skipping...
# Processing... | sehithwa
# Processing... | karakol
# Processing... | flinders
# Processing... | viedma
# Processing... | laguna
# Processing... | visnes
# city not found. Skipping...
# Processing... | lakes entrance
# Processing... | kochubey
# Processing... | clyde
# Processing... | encruzilhada do sul
# Processing... | hailey
# Processing... | wau
# Processing... | makakilo city
# Processing... | atar
# Processing... | sisimiut
# Processing... | urubicha
# Processing... | itoman
# Processing... | correderos
# Processing... | marsh harbour
# Processing... | mount gambier
# Processing... | kudirkos naumiestis
# Processing... | napasar
# Processing... | husavik
# Processing... | lasa
# Processing... | aksu
# Processing... | mahon
# Processing... | west wendover
# Processing... | moorhead
# Processing... | alvaraes
# city not found. Skipping...
# Processing... | isla mujeres
# Processing... | turbiv
# city not found. Skipping...
# Processing... | qaqortoq
# city not found. Skipping...
# Processing... | seoul
# city not found. Skipping...
# Processing... | bainbridge
# Processing... | formosa do rio preto
# Processing... | rawson
# Processing... | gasa
# Processing... | naron
# Processing... | utrecht
# Processing... | cuorgne
# Processing... | manaus
# Processing... | nkowakowa
# Processing... | dapaong
# Processing... | khuzhir
# Processing... | rabo de peixe
# Processing... | qingdao
# Processing... | jilin
# city not found. Skipping...
# Processing... | beringovskiy
# Processing... | san nicolas
# Processing... | keuruu
# Processing... | katsuura
# Processing... | west helena
# Processing... | reinosa
# Processing... | abaete
# city not found. Skipping...
# Processing... | punta alta
# Processing... | armenis
# Processing... | escarcega
# Processing... | bodaybo
# Processing... | emirdag
# Processing... | dubuque
# Processing... | denpasar
# Processing... | manggar
# Processing... | pospelikha
# Processing... | novosheshminsk
# Processing... | raichur
# Processing... | tsogni
# Processing... | griffith
# Processing... | ocampo
# Processing... | okrika
# Processing... | nueva florida
# Processing... | port macquarie
# Processing... | yar-sale
# Processing... | arman
# Processing... | goose creek
# Processing... | san policarpo
# Processing... | tual
# Processing... | ancud
# Processing... | castelo do piaui
# Processing... | buchanan
# Processing... | krasnoselkup
# Processing... | warrington
# Processing... | etah
# Processing... | jaguarao
# Processing... | kidal
# Processing... | pimentel
# Processing... | masunga
# city not found. Skipping...
# city not found. Skipping...
# Processing... | lancaster
# Processing... | matara
# Processing... | mount isa
# Processing... | sinegorye
# Processing... | mpanda
# Processing... | alakurtti
# Processing... | dawei
# Processing... | muros
# Processing... | itarema
# Processing... | tutoia
# Processing... | yibin
# Processing... | kiruna
# Processing... | markova
# Processing... | toora-khem
# Processing... | sokoni
# Processing... | klaksvik
# Processing... | san pedro de uraba
# Processing... | vestmannaeyjar
# Processing... | valleyview
# Processing... | chaoyang
# Processing... | bousso

# %%
weather_dict = {
    "City": ow_cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
ow_weather_df = pd.DataFrame(weather_dict)
ow_weather_df
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  Lebu          17      CL  1579819808        66 -37.62
# 1           Yellowknife          40      CA  1579819808        76  62.46
# 2                 Bluff          66      NZ  1579819809        64 -46.60
# 3         Mar del Plata          40      AR  1579819809        55 -38.00
# 4                Aykhal          11      RU  1579819809        65  66.00
# ..                  ...         ...     ...         ...       ...    ...
# 564  San Pedro de Uraba          20      CO  1579820004        74   8.28
# 565      Vestmannaeyjar         100      IS  1579820005        68  63.44
# 566          Valleyview          67      CA  1579820005        90  55.07
# 567            Chaoyang           0      CN  1579820005        63  41.57
# 568              Bousso           0      TD  1579820005        12  10.48
#
#         Lng  Max Temp  Wind Speed
# 0    -73.65    62.294     9.95465
# 1   -114.35    -4.000     8.05320
# 2    168.33    73.994     2.99758
# 3    -57.56    89.006    17.22490
# 4    111.50   -38.200     6.71100
# ..      ...       ...         ...
# 564  -76.38    82.400    13.86940
# 565  -20.27    34.304    39.10276
# 566 -117.29    29.282     3.17654
# 567  120.46    10.130     1.99093
# 568   16.71    66.956    11.54292
#
# [569 rows x 9 columns]

# %%
ow_weather_df.to_csv('ow_weather_df.csv',index=False)
# plot latitude vs temperature
lat_x = weather_dict['Lat']
temp_y = weather_dict['Max Temp']
plt.scatter(lat_x,temp_y,alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.show()
plt.savefig('lat_vs_temp.png')

# %%
# plot latitude vs humidity
plt.scatter(weather_dict['Lat'],weather_dict['Humidity'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
plt.savefig('lat_vs_humidity.png')

# %%
# plot latitude vs cloudiness
plt.scatter(weather_dict['Lat'],weather_dict['Cloudiness'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()
plt.savefig('lat_vs_cloudiness.png')

# %%
# plot latitude vs wind speed
plt.scatter(weather_dict['Lat'],weather_dict['Wind Speed'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
plt.savefig('lat_vs_wind_speed.png')

# %%
# plot latitude vs humidity
plt.scatter(weather_dict['Lat'],weather_dict['Humidity'],alpha=.5)
plt.grid(True)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
plt.savefig('lat_vs_humidity.png')

# %%
# isolate northern and southern hemisphere cities
northern_hem = []
southern_hem = []
northern_hem_cities = []
southern_hem_cities = []
northern_hem_temp = []
southern_hem_temp = []
northern_hem_hum = []
southern_hem_hum = []
northern_hem_cloud = []
southern_hem_cloud = []
northern_hem_wind = []
southern_hem_wind = []
for m in range(len(longitude)):
    if longitude[m] > 0:
        northern_hem.append(longitude[m])
        northern_hem_cities.append(ow_cities[m])
        northern_hem_temp.append(max_temp[m])
        northern_hem_hum.append(humidity[m])
        northern_hem_cloud.append(cloudiness[m])
        northern_hem_wind.append(wind_speed[m])
    else:
        southern_hem.append(longitude[m])
        southern_hem_cities.append(ow_cities[m])
        southern_hem_temp.append(max_temp[m])
        southern_hem_hum.append(humidity[m])
        southern_hem_cloud.append(cloudiness[m])
        southern_hem_wind.append(wind_speed[m])

# %%
#northern_hem
northern = {
    "City": northern_hem_cities,
    "Lat": northern_hem,
    "Max Temp": northern_hem_temp,
    "Humidity": northern_hem_hum,
    "Cloudiness": northern_hem_cloud,
    "Wind Speed": northern_hem_wind
}
north_df = pd.DataFrame(northern)

# southern hem
southern = {
    "City": southern_hem_cities,
    "Lat": southern_hem,
    "Max Temp": southern_hem_temp,
    "Humidity": southern_hem_hum,
    "Cloudiness": southern_hem_cloud,
    "Wind Speed": southern_hem_wind
}
south_df = pd.DataFrame(southern)

# plot northern hem lat vs temp
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Max Temp'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Max Temp'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temp')
ax.set_title('Latitude vs. Temperature')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: -0.06840588953731981

# %%
# plot southern hem lat vs temp
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Max Temp'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Max Temp'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,25),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temp')
ax.set_title('Latitude vs. Temperature')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.19013023356451242

# %%
# plot northern hem lat vs humidity
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Humidity'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Humidity'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('Latitude vs. Humidity')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.17139401041735608

# %%
# plot southern hem lat vs humidity
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Humidity'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Humidity'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.set_title('Latitude vs. Humidity')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.010518546659352437

# %%
# plot northern hem lat vs cloudiness
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Cloudiness'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Cloudiness'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')a
ax.set_ylabel('Cloudiness (%)')
ax.set_title('Latitude vs. Cloudiness')
print(f"The r-squared value is: {rvalue}")
# Out:
#   File "<ipython-input-128-0809b6269226>", line 10
#     ax.set_xlabel('Latitude')a
#                              ^
# SyntaxError: invalid syntax

# %%
# plot southern hem lat vs cloudiness
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Cloudiness'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Cloudiness'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.set_title('Latitude vs. Cloudiness')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.232636995225133

# %%
# plot northern hem lat vs wind speed
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'],north_df['Wind Speed'])
regress_values = north_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(north_df['Lat'],north_df['Wind Speed'],alpha=0.25)
ax.plot(north_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(50,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.set_title('Latitude vs. Wind Speed')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: -0.15835884217924787

# %%
# plot southern hem lat vs wind speed
# add linear regression equation and line to plot
fig, ax = plt.subplots()
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'],south_df['Wind Speed'])
regress_values = south_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
ax.scatter(south_df['Lat'],south_df['Wind Speed'],alpha=0.25)
ax.plot(south_df['Lat'],regress_values,"r-")
ax.annotate(line_eq,(-125,15),fontsize=15,color='red')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.set_title('Latitude vs. Wind Speed')
print(f"The r-squared value is: {rvalue}")
# Out:
# The r-squared value is: 0.13541324953720585
