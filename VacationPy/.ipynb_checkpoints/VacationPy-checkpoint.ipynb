# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json
import pprint

# Import API key
from api_keys import g_key

# configure gmaps
gmaps.configure(api_key=g_key)

# %%
cities_df = pd.read_csv('../WeatherPy/ow_weather_df.csv')
cities_df.dropna()
cities_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Lebu          17      CL  1579819808        66 -37.62  -73.65
# 1    Yellowknife          40      CA  1579819808        76  62.46 -114.35
# 2          Bluff          66      NZ  1579819809        64 -46.60  168.33
# 3  Mar del Plata          40      AR  1579819809        55 -38.00  -57.56
# 4         Aykhal          11      RU  1579819809        65  66.00  111.50
#
#    Max Temp  Wind Speed
# 0    62.294     9.95465
# 1    -4.000     8.05320
# 2    73.994     2.99758
# 3    89.006    17.22490
# 4   -38.200     6.71100

# %%
# store latitude and longitude in locations
locations = cities_df[['Lat','Lng']]
# store humidity as rating
rating = cities_df['Humidity'].astype(float)
# plot heatmap
fig = gmaps.figure(center=(0, 0),zoom_level = 2)
# create heat layer
heat_layer = gmaps.heatmap_layer(locations,weights=rating,\
                                 dissipating=True,max_intensity=400,\
                                 point_radius=20)
# add layer
fig.add_layer(heat_layer)
# display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# narrow down cities with ideal vacation weather
# max temp between 70 - 80 F
# wind speed < 10 mph
# cloudiness == 0
ideal_weather_df = cities_df.loc[(cities_df['Cloudiness']==0) &
                                (cities_df['Max Temp'].between(70,85)) &
                                (cities_df['Wind Speed']<10)].reset_index(drop=True)

ideal_weather_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Kankon           0      IN  1579819860        48  15.02   74.02
# 1        Valdivia           0      CL  1579819872        47 -39.81  -73.25
# 2  Puerto Penasco           0      MX  1579819890        48  31.32 -113.53
# 3            Sola           0      VU  1579819906        66 -13.88  167.55
# 4         Ahipara           0      NZ  1579819944        71 -35.17  173.17
# 5  Lakes Entrance           0      AU  1579819973        43 -37.88  147.98
# 6       Escarcega           0      MX  1579819989        51  18.61  -90.75
# 7          Matara           0      LK  1579819819        87   5.95   80.54
#
#    Max Temp  Wind Speed
# 0    75.470     5.83857
# 1    75.200     9.17170
# 2    71.996     5.01088
# 3    82.202     8.74667
# 4    84.002     1.99093
# 5    71.006     2.99758
# 6    77.000     3.24365
# 7    73.400     7.53869

# %%
ideal_lat = ideal_weather_df['Lat']
ideal_lng = ideal_weather_df['Lng']
# list to store hotel names
hotel_names = []
# lists to store hotel lat & lng
hotel_lat = []
hotel_lng = []
hotel_country = []
# len(ideal_lat)
# print(ideal_lat[0])
# print(ideal_lng[0])
for lat_lng in range(len(ideal_weather_df)):
    # print(ideal_lat[lat_lng])
    # print(ideal_lng[lat_lng])
    # base url
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    # set up parameters
    params = {
        'location': f'{ideal_lat[lat_lng]},{ideal_lng[lat_lng]}',
        'keyword': 'hotel',
        'radius': 5000,
        'type': 'hotel',
        'key': g_key
    }
    print(params)
    # run request by passing in parameters dictionary
    hotel_response = requests.get(base_url,params=params)
    # convert response to json
    hotel_data = hotel_response.json()
    pprint.pprint(hotel_data)
    if hotel_data['status']!='ZERO_RESULTS':
        # add hotel data to hotel_names, hotel_lat, hotel_lng lists
        hotel_names.append(hotel_data['results'][0]['name'])
        hotel_lat.append(hotel_data['results'][0]['geometry']['location']['lat'])
        hotel_lng.append(hotel_data['results'][0]['geometry']['location']['lng'])
        hotel_country.append(ideal_weather_df['Country'][lat_lng])
    else:
        hotel_names.append(hotel_data['status'])
        hotel_lat.append(hotel_data['status'])
        hotel_lng.append(hotel_data['status'])
        hotel_country.append(ideal_weather_df['Country'][lat_lng])
# Out:
# {'location': '15.02,74.02', 'keyword': 'hotel', 'radius': 5000, 'type': 'hotel', 'key': 'AIzaSyA_Yn5p6Gbhrq8r5Jf5zFaA5R0t10mexyI'}
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAAFOyMKNxdwERczNkDcq3qgDc5QaBTItYfsnIW1Z2me_CX74E2Gsw2x3fQ17pu4r-SOkXw8l0h0mDLxKGJHgSCZOHxAhQt1KNOwnHy9HSzrMbNCsGJ9repzOtPHBzjXqU1XA-PkY3maLoYrHslzcnEuIqrP8PrurquhPvT2YgNdn9gkK9cd1vndzHc9FrVT4rXzXZukJ4cwS6l64nHIIejxjYPxDtMZi57YHOLeVz60aDywI1YM1CEfdg6ymCEmcROlbYXV531xC6gBlBnQYxQ91D6sKjL5VvEjw3sDyHa_m-NK81-B-DgNTRKJwbYq0nJAF5cSW1pI53Ei4TEwERIt0i2iCOboTYKWgxESmpjOVJU1hxd8EiTqOdCd68jNAZ59qs6i-ZTlfKI87YOuIVgMgSEHMJnwCqpAXoNr3c-h-Kd4UaFNcWlDYmdofeUWI23WO4YG7f6o9t',
#  'results': [{'geometry': {'location': {'lat': 14.991011,
#                                         'lng': 74.04016899999999},
#                            'viewport': {'northeast': {'lat': 14.99234872989272,
#                                                       'lng': 74.04161817989272},
#                                         'southwest': {'lat': 14.98964907010728,
#                                                       'lng': 74.03891852010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'dd8b716f2719b3fb46167d95134d8f25e29f61d3',
#               'name': 'The LaLiT Golf & Spa Resort Goa',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106565121644149249151">Ольга '
#                                                 'Спиридонова</a>'],
#                           'photo_reference': 'CmRaAAAARrSusWCWjIsJfa6sC77_KAKNLufitA5ou-CXXzhZk5McZjwUIlXCkIJbSYU0Vr6vcNP_HHdZLf_VV29im7-A-umF3sHafDukdb9Xr2yTgMv0DA21ZNMX941UR2HMitITEhBc7VaGwEUMb3OUP1MvGTe5GhRLsKrii3kQ_eg03iMB6qKqZjyY2Q',
#                           'width': 4032}],
#               'place_id': 'ChIJtZICFc9avjsRU-uniR8sS5o',
#               'plus_code': {'compound_code': 'X2RR+C3 Canacona, Goa, India',
#                             'global_code': '7J6PX2RR+C3'},
#               'rating': 4.4,
#               'reference': 'ChIJtZICFc9avjsRU-uniR8sS5o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 6767,
#               'vicinity': 'Raj Baga, Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 15.0520824,
#                                         'lng': 73.98268379999999},
#                            'viewport': {'northeast': {'lat': 15.05340847989272,
#                                                       'lng': 73.98405647989271},
#                                         'southwest': {'lat': 15.05070882010728,
#                                                       'lng': 73.98135682010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '1c79146f6d7d9cfd0103f1ea4d0ed43a28159081',
#               'name': 'Agonda Beach Villa',
#               'photos': [{'height': 640,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102551173254455941564">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAArgTcJjlnRuC8TCYG9Uv8KRzdEYz0uNAh-txtN1nkr3vmYjS2c6T8HDlFcSQe5hJPQI5RJcZvW--Q7F6fX2QEJ4ozz-jnTv_HGnkk8zd_gX8wjqLPbPOyAgm_L-1-z-lVEhB7FuZWUOj-x4QFfYuXCzz2GhRroMMQgV9umGevgzEwwEc_spGnyw',
#                           'width': 960}],
#               'place_id': 'ChIJcfIBMM1PvjsRJ5jWBNMMaHQ',
#               'plus_code': {'compound_code': '3X2M+R3 Agonda, Goa, India',
#                             'global_code': '7J7M3X2M+R3'},
#               'rating': 5,
#               'reference': 'ChIJcfIBMM1PvjsRJ5jWBNMMaHQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Behind H.No. 261/A, Dhaval Khazan Agonda Beach, '
#                           'Agonda'},
#              {'geometry': {'location': {'lat': 15.0036027, 'lng': 74.0267041},
#                            'viewport': {'northeast': {'lat': 15.00478467989272,
#                                                       'lng': 74.02802352989272},
#                                         'southwest': {'lat': 15.00208502010728,
#                                                       'lng': 74.02532387010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ca1cd312e4a92fd3d09af673d332fb4a1be7ef74',
#               'name': 'Pacific Sunset View Resort',
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102202583383308636721">Сергей '
#                                                 'Калиниченко</a>'],
#                           'photo_reference': 'CmRaAAAAUtssqXoMvy8wq5POrOQgAqN5ERWZyJJz5b21-1Z1GIZCYY0MVMjEE8wZV4pdt1cfUEP4715lK9SOwvjhCegh6Yvzwn2gZBv5joRT2wNTSxP_RnXPdarz7f4HbdbldWpJEhARR7viJls0fbyk1q5XmfJ7GhSv_IwxQ0K5bV__iZR0wZqSr9QgHg',
#                           'width': 3888}],
#               'place_id': 'ChIJKyFae0xFvjsRSmvSxZa0Qkc',
#               'plus_code': {'compound_code': '223G+CM Canacona, Goa, India',
#                             'global_code': '7J7P223G+CM'},
#               'rating': 4.6,
#               'reference': 'ChIJKyFae0xFvjsRSmvSxZa0Qkc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 47,
#               'vicinity': 'Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 15.0316232, 'lng': 73.9908449},
#                            'viewport': {'northeast': {'lat': 15.03291437989272,
#                                                       'lng': 73.99233592989272},
#                                         'southwest': {'lat': 15.03021472010728,
#                                                       'lng': 73.98963627010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '627929e45b6efae905ef7d57a8222fe217940189',
#               'name': 'SummerSky Beach Resort and Caffe Mudra',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2916,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106051014693185040250">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAd9hoUJPYGcD-9AulFFyizt6Ov8dcaeGnHlm-2kkDqZxvgzCYPnBCKK0Pp7HEjc18IdPQD8wiT25an9nDLipdNvnxtw6f7fgJnhDCafgZmZUtVh0HgcGxzyKIZW69LlelEhAA2oqFMCGXlyrtPQbvjHYQGhQMrtMlsMoikLXoaFxL6nUxxIONTg',
#                           'width': 5184}],
#               'place_id': 'ChIJYTqGlg1PvjsRFFfYZqLZG3o',
#               'plus_code': {'compound_code': '2XJR+J8 Canacona, Goa, India',
#                             'global_code': '7J7M2XJR+J8'},
#               'rating': 4.6,
#               'reference': 'ChIJYTqGlg1PvjsRFFfYZqLZG3o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 23,
#               'vicinity': 'Tambdem Agonda, Canacona'},
#              {'geometry': {'location': {'lat': 15.0062335,
#                                         'lng': 74.03294989999999},
#                            'viewport': {'northeast': {'lat': 15.00764662989272,
#                                                       'lng': 74.03431047989272},
#                                         'southwest': {'lat': 15.00494697010728,
#                                                       'lng': 74.03161082010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e05c9d29608d3ea075f885f544ef0abc43ff93b8',
#               'name': 'Hotel Sea Shine - best hotels in Palolem Beach | best '
#                       'hotel in GOA',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 853,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106871182771572640068">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA9LLKNwSMwiTQTG5QUR68aUmi7E18tRvbLR91PdV3wy-Tw-mpaurm0VKyT_8ze11u04JMcQSNTSMWGQS4qJmiJLiwSapByRdRU8LtJKkMyjc7CiA2GIWCxxQoU-nc-5bNEhCphtWDOeC27g-6kr0W9HRuGhSpTJ9AU_NbZoygzYzItxFCjKEVvw',
#                           'width': 1280}],
#               'place_id': 'ChIJIVgnvedbvjsRxQ9dzEgrswI',
#               'plus_code': {'compound_code': '224M+F5 South Goa, Goa, India',
#                             'global_code': '7J7P224M+F5'},
#               'rating': 4.9,
#               'reference': 'ChIJIVgnvedbvjsRxQ9dzEgrswI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 32,
#               'vicinity': 'H.NO. 93 / 1, Situated at Cafe Coffee Day Ward No. '
#                           '10, Palolem, Canacona, South'},
#              {'geometry': {'location': {'lat': 15.0075042,
#                                         'lng': 74.02729339999999},
#                            'viewport': {'northeast': {'lat': 15.00882027989272,
#                                                       'lng': 74.0285995298927},
#                                         'southwest': {'lat': 15.00612062010728,
#                                                       'lng': 74.02589987010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '6b33fe5dc1c730af0fc73e5516a394a987f4b804',
#               'name': "Kate's Cottages",
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106964647516984227248">Simeon '
#                                                 'Mark Fernandes</a>'],
#                           'photo_reference': 'CmRaAAAAelQt3aVhKo_rPZdbiREHdjaZVreEFoSDatcBT2JGLZDPOzmadlT9DAYaGP3ZJVGzsuAuyZQFU_lDT219pVtM9g8BPNIgiP4D6bLK7QkQGU4Peq4s9_sOCw-hKb2uL7wEEhDcikO-6SJZUghs4RUSnTEFGhQWy8Z9pRDfpTk8fbf-GUM8kVbQIw',
#                           'width': 4608}],
#               'place_id': 'ChIJe0xIdE1FvjsRsYSpaHe5Kdg',
#               'plus_code': {'compound_code': '225G+2W Canacona, Goa, India',
#                             'global_code': '7J7P225G+2W'},
#               'rating': 4.4,
#               'reference': 'ChIJe0xIdE1FvjsRsYSpaHe5Kdg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 47,
#               'vicinity': "Above Fern's By Kate's BAR & RESTAURANT, Ourem "
#                           'Vaddo, behind Hi- Tide Coco Huts South End of the '
#                           'Palolem Beach, Canacona'},
#              {'geometry': {'location': {'lat': 15.0086571, 'lng': 74.0275485},
#                            'viewport': {'northeast': {'lat': 15.01000332989272,
#                                                       'lng': 74.02890392989272},
#                                         'southwest': {'lat': 15.00730367010728,
#                                                       'lng': 74.02620427010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '7a32569ae3643b45c59854e6a01fb7ec72fd9c45',
#               'name': 'Neptune Point Premium Resort',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 482,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101966531410314759194">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA_Bzoz09eYTWj7oRIhHSNZRJLnmCcFMOzz0_gVk9oixr22eWV58tiqZoyJ6eM5UkAGk3X49SLpDfogkU4oyr9m_gibglmAY2ifbm2HrW6kjHqkMyPJfKN_0dXqxgdK8z6EhDYSAJ3RU77JoO1ZJKM-2U5GhS0R58Yyr9HXUymHhFcVHcYuDtj7Q',
#                           'width': 720}],
#               'place_id': 'ChIJ91IwTldFvjsRgc4GvaZX1Wc',
#               'plus_code': {'compound_code': '225H+F2 Palolem, Canacona, Goa, '
#                                              'India',
#                             'global_code': '7J7P225H+F2'},
#               'rating': 5,
#               'reference': 'ChIJ91IwTldFvjsRgc4GvaZX1Wc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Ourem Rd, Mohanbagh, Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 15.0455113,
#                                         'lng': 73.98590159999999},
#                            'viewport': {'northeast': {'lat': 15.04687657989272,
#                                                       'lng': 73.9874001798927},
#                                         'southwest': {'lat': 15.04417692010728,
#                                                       'lng': 73.98470052010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '2e4a4814d6247059975cc4ac4a7529a864221cba',
#               'name': 'Agonda Serenity Resort',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 640,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100166123930517203749">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA2nmbsTjBTpOBYVwlp41HYWvH6dNYsAwHejaCUYtbKUhS_3hKbp54JbNdMsBZGq2-Nk4hz8eQmtgZeBtWkQ4LMD-Cw18ULapqhhsPLt6AQvoeNc-iqq4RuZPVG2ujiriYEhAZzqAD88KWAFWc9lmwPUKlGhTzt5oni7le1fBq_qCBqjR_m4u13w',
#                           'width': 960}],
#               'place_id': 'ChIJ624mk8lPvjsRex2BsYqOKss',
#               'plus_code': {'compound_code': '2XWP+69 Agonda, Goa, India',
#                             'global_code': '7J7M2XWP+69'},
#               'rating': 4.5,
#               'reference': 'ChIJ624mk8lPvjsRex2BsYqOKss',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 115,
#               'vicinity': 'Agonda Beach Rd, Agonda'},
#              {'geometry': {'location': {'lat': 15.0535652, 'lng': 73.9823814},
#                            'viewport': {'northeast': {'lat': 15.05491802989273,
#                                                       'lng': 73.98382732989272},
#                                         'southwest': {'lat': 15.05221837010728,
#                                                       'lng': 73.98112767010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'c53197bd35f07c200ce1a5dfb23733d6ad58d765',
#               'name': 'The Bay Agonda',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 853,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102394830297145062913">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAJik9-tuuAoJs80g-iHyYg7raWfCQXGHiWbhz-rzevIyPuiPm1cpmtiA-LObTymh9cBv6ykUUO1Ox0INac--Y4tv8qzD-oaXPZQIgPtUfpmNZpeHBYIvxHmIZ9tgjV-SkEhDxrNa-lxRW_1fkxErzKyIbGhREPERlYtycnUPKpo05huZ1IzPfpg',
#                           'width': 1280}],
#               'place_id': 'ChIJPa3RAQdPvjsRDwlKDYsxpdo',
#               'plus_code': {'compound_code': '3X3J+CX Agonda, Goa, India',
#                             'global_code': '7J7M3X3J+CX'},
#               'rating': 4.7,
#               'reference': 'ChIJPa3RAQdPvjsRDwlKDYsxpdo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 436,
#               'vicinity': 'Near, Bridge, Salleri, Agonda'},
#              {'geometry': {'location': {'lat': 15.0054513, 'lng': 74.0271781},
#                            'viewport': {'northeast': {'lat': 15.00681062989272,
#                                                       'lng': 74.02849732989272},
#                                         'southwest': {'lat': 15.00411097010728,
#                                                       'lng': 74.02579767010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3fa7bcc9bafc8a2ee4ba68262c3f785433ee9372',
#               'name': 'Marron Sea View Resort',
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114775891537682872688">Marron '
#                                                 'Beach Resort</a>'],
#                           'photo_reference': 'CmRaAAAA8xncoX7djtPSQ-vktuBvSWKnwrhDk5KowNHSZjN7UZv1blF19uMGtV59t5r0zpKo5RAKOPLBn2TYnrU5sQScKBQQFS7bDnqYPrTawIJD551suD5KPCpn4OsUv4Nqmo3DEhCJeuGnQ_qjA_B-AU4BydGSGhR27el_gX6I3v7W55yMFIbJkxOrOQ',
#                           'width': 2048}],
#               'place_id': 'ChIJA6Ud-ExFvjsRXSjePwl17ls',
#               'plus_code': {'compound_code': '224G+5V Palolem, Canacona, Goa, '
#                                              'India',
#                             'global_code': '7J7P224G+5V'},
#               'rating': 4.2,
#               'reference': 'ChIJA6Ud-ExFvjsRXSjePwl17ls',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 480,
#               'vicinity': 'Left End of the beach, Ourem Rd, Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 15.056445, 'lng': 73.971789},
#                            'viewport': {'northeast': {'lat': 15.05759747989272,
#                                                       'lng': 73.97302032989273},
#                                         'southwest': {'lat': 15.05489782010728,
#                                                       'lng': 73.97032067010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '90fd3ffa12128c2069c1852aaa633ef3abbd2071',
#               'name': 'Dwarka Eco Beach Resort',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1397,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117159241887839205959">Dwarka '
#                                                 'Eco Beach Resort</a>'],
#                           'photo_reference': 'CmRaAAAAD23z4Aaz7IFlq_jDF30IuB0kifxQ1QvjdKBLblCJCRz5MEtAxUzn7UFIADbChaT5DOWkCodeA80ApOobwLf1FxwfQpogemZWNDy-f66Ha7eCofvbiJlil6cyijxOQWmDEhCpEXc4cD_GtDbLWTqMmOtuGhQFm2qrrqp56F9r1oC9orf_FSgOgA',
#                           'width': 2096}],
#               'place_id': 'ChIJ_4oyTgNPvjsRQsGBOg-m3XI',
#               'plus_code': {'compound_code': '3X4C+HP Cola, Goa, India',
#                             'global_code': '7J7M3X4C+HP'},
#               'rating': 4.5,
#               'reference': 'ChIJ_4oyTgNPvjsRQsGBOg-m3XI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 96,
#               'vicinity': 'Cola Beach Road, Mattimol, Canacona, Cola'},
#              {'geometry': {'location': {'lat': 15.0066071,
#                                         'lng': 74.02672319999999},
#                            'viewport': {'northeast': {'lat': 15.00767972989272,
#                                                       'lng': 74.02831962989272},
#                                         'southwest': {'lat': 15.00498007010728,
#                                                       'lng': 74.02561997010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'fb87f3e1ceafe608e9320e5a4d3ff1a74441b621',
#               'name': 'Art Resort Goa',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108806929373045620583">Art '
#                                                 'Resort Goa</a>'],
#                           'photo_reference': 'CmRaAAAAEqDYw3LWcAinZW9FazZrzaZiKzcPycHK8dY5KHXuU1CHZM4dBdawCG8_q5GfCoj8o2QPKUCTpzGE4OCq21oPgq5Jnfdxapw1tRf1vPYo9Vl84C1IV14kTS1B0wUQDXT9EhDRiLmonTqbrI5CNbfuF3zXGhQZilsGlEVsPc1t8FOEkFQJVmYweA',
#                           'width': 4032}],
#               'place_id': 'ChIJOwHQUkxFvjsRkV_QTSxplLM',
#               'plus_code': {'compound_code': '224G+JM Palolem, Canacona, Goa, '
#                                              'India',
#                             'global_code': '7J7P224G+JM'},
#               'rating': 4.4,
#               'reference': 'ChIJOwHQUkxFvjsRkV_QTSxplLM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 347,
#               'vicinity': '103/11 ourem road, south, Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 14.999622, 'lng': 74.0317091},
#                            'viewport': {'northeast': {'lat': 15.00096742989272,
#                                                       'lng': 74.03300972989273},
#                                         'southwest': {'lat': 14.99826777010728,
#                                                       'lng': 74.03031007010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '7bbf922b0a73884ea791cd6635c1918ca1b01dfe',
#               'name': 'Nada Brahma Resort',
#               'photos': [{'height': 1066,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105761121600719707540">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAApQRAa0fVXpZMCK_r_-30gJKNRpKWls_8yqbhAnBKowp3zKXQkWU-1Hv2stTn-oSAMX9RmSXc16PcoZCtnyaBpaOs82mA0fK-z24zEbRkyCuXzlql50QXZJgAJQ2IsJevEhCu5tx6yRSzLIQrw56eIKCuGhS1NsKcKRAKRV61UHeHpScYiA2y9w',
#                           'width': 1600}],
#               'place_id': 'ChIJI6Ffm3VbvjsRrkFXaTxGWAQ',
#               'plus_code': {'compound_code': 'X2XJ+RM Canacona, Goa, India',
#                             'global_code': '7J6PX2XJ+RM'},
#               'rating': 4.9,
#               'reference': 'ChIJI6Ffm3VbvjsRrkFXaTxGWAQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 21,
#               'vicinity': 'Patnem, Canacona'},
#              {'geometry': {'location': {'lat': 15.013353, 'lng': 74.0191146},
#                            'viewport': {'northeast': {'lat': 15.01529482989272,
#                                                       'lng': 74.02056562989272},
#                                         'southwest': {'lat': 15.01259517010728,
#                                                       'lng': 74.01786597010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9795185ccdfafd449afd0a97bda3e5f8e83c06ae',
#               'name': 'Palm Forest Palolem',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1606,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106630199540263886790">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAANE1IfwWQ1h_LeZeYLJ3v8NShsM7einPO1nBFyo_mZ7v1XpaM9yoh9Jy2fxVEbDCtQ6yCGEUy6Wx5OeXnbNn4iBU5bGdT7joQnt6er_nGFTK2bl-OPOnqWLXpJ7f1DjoGEhC915Lwx-0vxoUISn9SAKANGhQOwMyIOuAjENSb_q3RDObB9xovwQ',
#                           'width': 2406}],
#               'place_id': 'ChIJt9tsslBFvjsRzUdco_AG2WU',
#               'plus_code': {'compound_code': '2279+8J Palolem, Canacona, Goa, '
#                                              'India',
#                             'global_code': '7J7P2279+8J'},
#               'rating': 4.7,
#               'reference': 'ChIJt9tsslBFvjsRzUdco_AG2WU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 42,
#               'vicinity': 'Palolem Down St, Behind St. Cruz Chapel, Palolem, '
#                           'Canacona'},
#              {'geometry': {'location': {'lat': 15.0434621,
#                                         'lng': 73.98767819999999},
#                            'viewport': {'northeast': {'lat': 15.04477142989272,
#                                                       'lng': 73.98895767989272},
#                                         'southwest': {'lat': 15.04207177010728,
#                                                       'lng': 73.98625802010729}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '2ab35cac62a97d9a514ced98ac56a6afb3ac8886',
#               'name': 'Mahi Agonda',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112029463809346352429">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAdeF8qZ1Afk2cBoJmY4v7CklXomXCOHQfDU3vazrj65S70KMRucuKZQRNRllyzO_95AbDE4l7UUtOi0q0DaL7D0y7EXvx-e_D1LFjEZmFAmk94rqBMNtyPIccxix6V8IgEhAvCi7URnkKrUXmmR4RbEohGhQvIE1M5URHY7HICAraTDkkis9VTg',
#                           'width': 3024}],
#               'place_id': 'ChIJMbEQ62dPvjsRrk_mQYljTzA',
#               'plus_code': {'compound_code': '2XVQ+93 Agonda, Goa, India',
#                             'global_code': '7J7M2XVQ+93'},
#               'rating': 4.7,
#               'reference': 'ChIJMbEQ62dPvjsRrk_mQYljTzA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'House no 339/1, Agonda'},
#              {'geometry': {'location': {'lat': 15.0355668, 'lng': 73.9981342},
#                            'viewport': {'northeast': {'lat': 15.03692632989272,
#                                                       'lng': 73.99948517989272},
#                                         'southwest': {'lat': 15.03422667010728,
#                                                       'lng': 73.99678552010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '0550636930317b50a5cb5a83748e7c53c564e3b6',
#               'name': 'Tina Beach Resort',
#               'photos': [{'height': 612,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109541502422281853812">Иван '
#                                                 'Чистов</a>'],
#                           'photo_reference': 'CmRaAAAA5gGqV-396RVhlRuTrHcXJvf_tHtr19a_T-bny8bXHgzqZClKhx9zXrM7F1JqnrSrzHct28dmdpXtUbnd7GZXrHxvQVxxaIIH_XsY8MH_sbJnaywFkzIEvGJDuubUDJKYEhDn3uxDqjaESedUPzv0Vt1IGhQsKnvaHFJB3AM9gJ_J2JpF8KEssw',
#                           'width': 816}],
#               'place_id': 'ChIJedsXWJ9PvjsR8bXO_zR-oFg',
#               'plus_code': {'compound_code': '2XPX+67 Agonda, Goa, India',
#                             'global_code': '7J7M2XPX+67'},
#               'rating': 5,
#               'reference': 'ChIJedsXWJ9PvjsR8bXO_zR-oFg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': '394/4, Agonda'},
#              {'geometry': {'location': {'lat': 15.0019749, 'lng': 74.0299639},
#                            'viewport': {'northeast': {'lat': 15.00330887989272,
#                                                       'lng': 74.03125947989271},
#                                         'southwest': {'lat': 15.00060922010727,
#                                                       'lng': 74.02855982010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '35e053772a4b2a0780750589438933e873e66d33',
#               'name': 'La la land Resort',
#               'photos': [{'height': 1728,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101979112340853956066">Gaurav '
#                                                 'Kumar</a>'],
#                           'photo_reference': 'CmRaAAAAGJpD7UttEEyVcgi_Ld0Tu9vZceEpS1s3__gskL2kP86lYuleWsCbKU2qxm6R5_dP4CyM0O9Pp3ged566Bx3Kz6ZbaQjHDCpMT0syV3QCehOzCnnqH0_eCr-VEpzMSBamEhCeflp3BF5FnQkAWmBCyyQqGhRGiX5xYkpwMurOKa8f3fejND4rTw',
#                           'width': 3072}],
#               'place_id': 'ChIJZejIpUxFvjsRefxsnoafJdM',
#               'plus_code': {'compound_code': '222H+QX Canacona, Goa, India',
#                             'global_code': '7J7P222H+QX'},
#               'rating': 4.1,
#               'reference': 'ChIJZejIpUxFvjsRefxsnoafJdM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 143,
#               'vicinity': 'Colomb beach Road Canacona near patnem beach '
#                           'Patnem'},
#              {'geometry': {'location': {'lat': 15.0107681, 'lng': 74.0229131},
#                            'viewport': {'northeast': {'lat': 15.01254262989272,
#                                                       'lng': 74.02360800000001},
#                                         'southwest': {'lat': 15.00984297010728,
#                                                       'lng': 74.0208284}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '42c7a6221ca3fbe7dd6e351f2ea6c0270646cce8',
#               'name': 'Ciarans',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 600,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109413722468105978840">Ciarans</a>'],
#                           'photo_reference': 'CmRaAAAAb-72BHd791zdIs3BcT577mrcedoCI8RCD_5Ta5imvQolbeqf9bY2Kj5fxYR4dWckv8P__2yc7G0xi-sospCvN5-TfJxIWL9hnk7LFjDJWUqab8Lw9e9hCaf_yULhSquBEhAQADVFkqxlN1bNBfR--pb-GhRmXiMr55xxqpvMfveTh3vecnEiMQ',
#                           'width': 919}],
#               'place_id': 'ChIJR4Sgn1FFvjsRLvyn6LQV190',
#               'plus_code': {'compound_code': '226F+85 Canacona, Goa, India',
#                             'global_code': '7J7P226F+85'},
#               'rating': 4.2,
#               'reference': 'ChIJR4Sgn1FFvjsRLvyn6LQV190',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 280,
#               'vicinity': 'H:no. 233/A, Palolem Beach, Palolem, behind Old '
#                           'Syndicate Bank, Canacona'},
#              {'geometry': {'location': {'lat': 15.0013013, 'lng': 74.0327458},
#                            'viewport': {'northeast': {'lat': 15.00263322989272,
#                                                       'lng': 74.03408722989272},
#                                         'southwest': {'lat': 14.99993357010728,
#                                                       'lng': 74.03138757010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '1b275b2d4efed5d4fdef593db392b17710bdb73a',
#               'name': 'Villa Aadhya GOA',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115920000197529115383">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA4eruQgZAXlP15HeFEe_rTiEErIK9wzNmCI2KZVnfDxuewlkv164iU1whmeoaj9HzeTS1eYauZnRCu7mF5xYWf9rxuHChTDC6A3lEwH5vp5jFXjtsSKdLIwkZjtex7_-tEhCY_ltSXODLILyUGz6tJhRcGhSQEnR2i-daGpu5DErPZcsGJjD8ww',
#                           'width': 2000}],
#               'place_id': 'ChIJDVk4VaJbvjsRvBTLh4EWqn0',
#               'plus_code': {'compound_code': '222M+G3 Palolem, Canacona, Goa, '
#                                              'India',
#                             'global_code': '7J7P222M+G3'},
#               'rating': 5,
#               'reference': 'ChIJDVk4VaJbvjsRvBTLh4EWqn0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'Colomb bay,Near Palolem beach, patnem road, '
#                           'Palolem, Canacona'},
#              {'geometry': {'location': {'lat': 15.0118295, 'lng': 74.02116},
#                            'viewport': {'northeast': {'lat': 15.01310087989272,
#                                                       'lng': 74.02270592989272},
#                                         'southwest': {'lat': 15.01040122010728,
#                                                       'lng': 74.02000627010729}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3b6d0fdb43f118d6f53ad3f43007d63b0af2ba07',
#               'name': 'Palolem Beach Resort',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1939,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105513053663879602334">Palolem '
#                                                 'Beach Resort</a>'],
#                           'photo_reference': 'CmRaAAAA2oJAPH4xpDF0EyVUIvFtNWIbVy24Re1n0sGxdCESFWHHGNABHxJgzkmdUSxBzE12jh7YIpDf7V2TuiRuzBPRBCTMnU6fCAmYtliNAvQPYLfvQo8H-ik3i_9as_DNthjAEhBSLkd6-a21qHCLZ9K6P2tyGhQyxDZ2mT6Jj61I6vnNdQh2jOrYmg',
#                           'width': 2908}],
#               'place_id': 'ChIJlQju4lBFvjsRVuG6xDU3csw',
#               'plus_code': {'compound_code': '226C+PF Canacona, Goa, India',
#                             'global_code': '7J7P226C+PF'},
#               'rating': 4.2,
#               'reference': 'ChIJlQju4lBFvjsRVuG6xDU3csw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2562,
#               'vicinity': 'Palolem - Patnem Beach Road, Patnem, Canacona'}],
#  'status': 'OK'}
# {'location': '-39.81,-73.25', 'keyword': 'hotel', 'radius': 5000, 'type': 'hotel', 'key': 'AIzaSyA_Yn5p6Gbhrq8r5Jf5zFaA5R0t10mexyI'}
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAAF4nsMCi35txjLYwolrWuiJizqiNny_oVi1wqLTRrgh76003DiRrcgPMqmHHQTQVtlhKQkFrwlABdtvAfgMOWI8whYiJikpKzdex3UZU_F_XMyiNQDfpJaOJpSv85mUAjp2lLWuyY94jMrupRIjcsg9uFHxnjd9zwfZMC-O7XBYvtSjsmXqSsSnpobJ_eMyIJ6HosGsV_uThGnFdyDKmlOumkIz5cXsZpJXU4jj_jbg7YB83rpf6fucC0sdNMiT0JhpnA5TUHfSQQHH8PzjW0XWD6e3JqWujmHop-ukhINKZEXDktMWqHCDiK-_h4v7uYkZizfjAV1zPO1cw3o1JC1XBiYy5ccqfR6n2s2ckUoo9RwJZZStAOxlGfxR230Eh31KYDWvRdnCxTZgFD-5FCYwSEFlZAWiB4j_eVHB2e2xSp3UaFGSnY2Y27E94PRsCo9aUPZByG5ZW',
#  'results': [{'geometry': {'location': {'lat': -39.8165377, 'lng': -73.2324385},
#                            'viewport': {'northeast': {'lat': -39.81517702010727,
#                                                       'lng': -73.23107447010727},
#                                         'southwest': {'lat': -39.81787667989271,
#                                                       'lng': -73.23377412989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9268a525911a8f8df545b331ab70d18715770f98',
#               'name': 'Hotel Costanera, Valdivia - Centro Turístico Caja los '
#                       'Andes',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112318113952095829969">Centro '
#                                                 'Turístico Costanera - Caja '
#                                                 'los Andes</a>'],
#                           'photo_reference': 'CmRaAAAAS5Pe7x0nq6fEFMf9GuATYDq1izchCRioFuUHHDVpxCLpSsBUzkQ0KAiwI79i5MUNPpxP4q7OlkIcwh6l0ltAXOTVC8yapuhDUNjXMdq_KXQvpa38Po7b0JiY18C2ikwQEhD7ojJrY1VVkUjMPkqXzvsBGhTvV9Kj2sFKD-GKlORA0AkOhRYYaw',
#                           'width': 5184}],
#               'place_id': 'ChIJtbwOM3zuFZYRsCy0LGNTZZ4',
#               'plus_code': {'compound_code': '5QM9+92 Valdivia, Chile',
#                             'global_code': '47G85QM9+92'},
#               'rating': 4.5,
#               'reference': 'ChIJtbwOM3zuFZYRsCy0LGNTZZ4',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'lodging',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 243,
#               'vicinity': 'Av. Arturo Prat Nº 1035 Frente al Costanera Río '
#                           'Calle Calle'},
#              {'geometry': {'location': {'lat': -39.8114565, 'lng': -73.2466998},
#                            'viewport': {'northeast': {'lat': -39.81005577010727,
#                                                       'lng': -73.24545727010728},
#                                         'southwest': {'lat': -39.81275542989272,
#                                                       'lng': -73.24815692989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'b066f710e79f91d36dc4ea5d55034e55c964d88f',
#               'name': 'Hotel Dreams Pedro De Valdivia',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109011653176525059451">Eduardo '
#                                                 'Puelma</a>'],
#                           'photo_reference': 'CmRZAAAAcWGrycGdjhrg8A7muIGomv6ei9mwn88uNYMfyz41eWgvtVAVk_-CXWyO9KYL8WLes5P3aEKgPlDWJYV3Gox6sHCa2_CHHnat36c-0BsdPueoe78xA5WuZCdK1Fblqb9PEhCBU8MJvVbLGL0MPKTl_DXJGhSgek-N21AvunDRZxaWK350Ex4zMQ',
#                           'width': 1620}],
#               'place_id': 'ChIJz5SiA3juFZYRPYmWfmZahIQ',
#               'plus_code': {'compound_code': '5QQ3+C8 Valdivia, Chile',
#                             'global_code': '47G85QQ3+C8'},
#               'rating': 4.6,
#               'reference': 'ChIJz5SiA3juFZYRPYmWfmZahIQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1020,
#               'vicinity': 'Carampangue 190, Valdivia'},
#              {'geometry': {'location': {'lat': -39.8298759, 'lng': -73.2508071},
#                            'viewport': {'northeast': {'lat': -39.82852917010728,
#                                                       'lng': -73.24941627010729},
#                                         'southwest': {'lat': -39.83122882989272,
#                                                       'lng': -73.25211592989274}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '0071b0a053371aa2fe75513ea23581a8004dc884',
#               'name': 'Hotel Naguilan',
#               'photos': [{'height': 680,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112786144610989867703">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAfwDbqajt-HBOjS8huiAbLfH7n_q7HFHZrA17U6Tk7yh_FCIPy1Hu6qRyvZ5_jxWChwcJeB47kNkSr0oHI2QeUuugLTOUNQbb2ylf5C4sNXzXGJiTI-9Kuy774YyM_GnhEhBImsxXEO-qFHn2b-t4PNbqGhRFUc8dUcMwllQk0nBtD-ZhAFTpag',
#                           'width': 1024}],
#               'place_id': 'ChIJA7cvn2ruFZYRXASxHqA-4Xc',
#               'plus_code': {'compound_code': '5PCX+2M Valdivia, Chile',
#                             'global_code': '47G85PCX+2M'},
#               'rating': 4.4,
#               'reference': 'ChIJA7cvn2ruFZYRXASxHqA-4Xc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 489,
#               'vicinity': 'Gral Lagos 1927, Valdivia'},
#              {'geometry': {'location': {'lat': -39.820297, 'lng': -73.24937},
#                            'viewport': {'northeast': {'lat': -39.81895287010727,
#                                                       'lng': -73.24797742010728},
#                                         'southwest': {'lat': -39.82165252989272,
#                                                       'lng': -73.25067707989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ed7985fafe0399475ec5cdc44eb75dcd4e0d358d',
#               'name': 'Hotel Boutique Casona Borderio',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 400,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102579384637629186055">Casona '
#                                                 'Borderio</a>'],
#                           'photo_reference': 'CmRaAAAAjPdUH1A0DYonaaBXeAx0EbnWa0kGs7_RZEyhm3MaZvxGA9TLGRldEyWuLS2OYYqUpoi208GTS689GT1TWm0BVRCWoiFotzIhNTq4pNHjmt9Ao92BBl5PdFkZ640JvhdzEhDssRfy_iMTZUahUilseG5NGhQeJkKEyjUVz47wfgL8T06XAsG58Q',
#                           'width': 925}],
#               'place_id': 'ChIJ4Y7_znbuFZYR8MyswNB98Jc',
#               'plus_code': {'compound_code': '5QH2+V7 Valdivia, Chile',
#                             'global_code': '47G85QH2+V7'},
#               'rating': 4.3,
#               'reference': 'ChIJ4Y7_znbuFZYR8MyswNB98Jc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 198,
#               'vicinity': 'Gral Lagos 1036, Valdivia'},
#              {'geometry': {'location': {'lat': -39.8150766, 'lng': -73.2356622},
#                            'viewport': {'northeast': {'lat': -39.81370682010728,
#                                                       'lng': -73.23436102010729},
#                                         'southwest': {'lat': -39.81640647989273,
#                                                       'lng': -73.23706067989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'a373ad9cd6c8907fa72b2cb0467d8f4d7184bac6',
#               'name': 'Hotel Terrapuerto, Valdivia',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2322,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106461671223621131552">Rfittacorum '
#                                                 '.Cabula</a>'],
#                           'photo_reference': 'CmRaAAAA3eEW_vna4p6vNxVCgammsVfYdyxzLzKwi7rnxT81t2rDGkDrqqs3xfgkIrmz44TfRczRjXpIZPV9ELaB8VZ17tX3dfosoQsWlxd6Xc2YjTaj0mQyZP_GUeAtnRVN8WF1EhC2slP3H2ucNAl7UhvxduArGhRXUm5TM8hTY11dNbGcoeLbfciwYw',
#                           'width': 4128}],
#               'place_id': 'ChIJ_8BqOHnuFZYRthNUpHDzmNU',
#               'plus_code': {'compound_code': '5QM7+XP Valdivia, Chile',
#                             'global_code': '47G85QM7+XP'},
#               'rating': 4.3,
#               'reference': 'ChIJ_8BqOHnuFZYRthNUpHDzmNU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 52,
#               'vicinity': 'Anfión Muñoz 360, Valdivia'},
#              {'geometry': {'location': {'lat': -39.818038, 'lng': -73.2467568},
#                            'viewport': {'northeast': {'lat': -39.81664447010728,
#                                                       'lng': -73.24539477010728},
#                                         'southwest': {'lat': -39.81934412989272,
#                                                       'lng': -73.24809442989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e06be79c724205343de6bfbb5700865b4507ab00',
#               'name': 'Hotel Di Torlaschi',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1376,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114357778170110218277">Hotel '
#                                                 'y Cabañas Di Torlaschi</a>'],
#                           'photo_reference': 'CmRZAAAAdOtv1Tzgjtf9DN3MAOwRoFBy7uvts4bDZuPV9arNI5cTtx6pZIDeXjCuvg-o2bUBz_GzKslr7q8Ulta1jvu4WconK0i1aCUXmf2Szf8ArMPn7y_N36x1QGrcFpw-xFnKEhBJ_iM08xDGchwS7pHecgsGGhTkPQHU3VIR4tvHRJCuddjzODnskg',
#                           'width': 2048}],
#               'place_id': 'ChIJb60q_nPuFZYRnPDGzSVP9yY',
#               'plus_code': {'compound_code': '5QJ3+Q7 Valdivia, Chile',
#                             'global_code': '47G85QJ3+Q7'},
#               'rating': 4.5,
#               'reference': 'ChIJb60q_nPuFZYRnPDGzSVP9yY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 434,
#               'vicinity': 'Yerbas Buenas 283, Valdivia'},
#              {'geometry': {'location': {'lat': -39.8152222, 'lng': -73.2607993},
#                            'viewport': {'northeast': {'lat': -39.81392212010728,
#                                                       'lng': -73.25911937010729},
#                                         'southwest': {'lat': -39.81662177989272,
#                                                       'lng': -73.26181902989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'a94bc984a3a450bebffa0a3ac64771baa807526b',
#               'name': 'Hotel Puerta del Sur',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3264,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109408935520528102917">Pamela '
#                                                 'Salazar</a>'],
#                           'photo_reference': 'CmRaAAAAb_e5n29sRqH4BaBVTpxXar5LV6tbAy_2p1f2UBCL6MlNyfpX4kCU1I4om2Zz17AFgZkOx7bdKZ6jWUHiu-hoq4AnSXcXeEG717DF04dPcZoN9P3Jc4HwPU9qzBsCIKQuEhDM9f6TW9woKtpp-4MalGI5GhSOxhtWfelNM6oIzyX1nDkw2yfyLA',
#                           'width': 2448}],
# ...
#                                                       'lng': 80.5617689701073}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '329ecf8a82b97c2a99537a3036807bd0279a8886',
#               'name': 'RIVER LINE HOTEL',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2240,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107165336648602259845">Laxmi '
#                                                 'Sunar</a>'],
#                           'photo_reference': 'CmRaAAAAEE7Ai70UIcDSLLcaPKmlwwRW2kMeRyM7sw76OAXrk6RovLnw6l-Pl_aocRVQe9HxVXmfof5XV16zWl4kChW53LMxlqaehviFwVP96OaGQwe1rzLuow1WNEV_dXePgX88EhCWidcVu1oS9hqmiyvR6AL5GhRqFHdndnsLjWC6XKca7SdeFZTUvg',
#                           'width': 4608}],
#               'place_id': 'ChIJWxsT-d444ToRVpW83YKOP3I',
#               'plus_code': {'compound_code': 'WHX7+47 Matara, Sri Lanka',
#                             'global_code': '6MQ2WHX7+47'},
#               'rating': 4.2,
#               'reference': 'ChIJWxsT-d444ToRVpW83YKOP3I',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'NO-3D,NAWIMANA ROAD,WELLEWATHA, MATHARA'},
#              {'geometry': {'location': {'lat': 5.9375177, 'lng': 80.5151684},
#                            'viewport': {'northeast': {'lat': 5.938789479892722,
#                                                       'lng': 80.51621877989272},
#                                         'southwest': {'lat': 5.936089820107278,
#                                                       'lng': 80.51351912010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9d41a14683e856139305b6356c436e8f96a70ed5',
#               'name': 'Amazing Villa - Madiha',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 479,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115111142488665387143">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA-aQyOAt4lAixB8yBlqwhvsYCalbI5KRFQQgtzkRiHFztX7rFMrJSbTMFKOkv2n7GZ3HEz67ESFesQooKpIjSS_C1K2g7yxHNVSH6oTznm99MzacabjFUeYz1xnJmnj8DEhDfEtf17K1N-l1CtGSd2kRxGhSPGV9ePx9xMwBcwbo-fvuASr0ttQ',
#                           'width': 720}],
#               'place_id': 'ChIJkefdFuQ-4ToRBpI4HKD_e6Q',
#               'plus_code': {'compound_code': 'WGQ8+23 Matara, Sri Lanka',
#                             'global_code': '6MQ2WGQ8+23'},
#               'rating': 3.9,
#               'reference': 'ChIJkefdFuQ-4ToRBpI4HKD_e6Q',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'Beach Road, Madiha, Matara'},
#              {'geometry': {'location': {'lat': 5.9375769, 'lng': 80.509971},
#                            'viewport': {'northeast': {'lat': 5.939017079892722,
#                                                       'lng': 80.51126977989271},
#                                         'southwest': {'lat': 5.936317420107279,
#                                                       'lng': 80.50857012010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '2c7b6d192e8596c563ddce5df5a579404472d6e9',
#               'name': 'Stella Beach House',
#               'photos': [{'height': 1488,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117431817544145430920">Patrick '
#                                                 'Williams</a>'],
#                           'photo_reference': 'CmRaAAAAebL-hROyci9Ez_y_DENnEbIeqHxtyMKGXW57wO7coOtinSz0fdHC0erVnO8FcI0E6Aootzlb33vRg3zTzKni0ToToxkHynyQhtGzXfhq882zrnDMK6agcudTP6YK6XQHEhAYx4KqDulDvRAakcZ5bRVKGhSiV_BIYsuKzMY2VoUZ9OE4epWelg',
#                           'width': 2240}],
#               'place_id': 'ChIJL1UgT_s-4ToRokKrXIPQSOE',
#               'plus_code': {'compound_code': 'WGQ5+2X Matara, Sri Lanka',
#                             'global_code': '6MQ2WGQ5+2X'},
#               'rating': 4.4,
#               'reference': 'ChIJL1UgT_s-4ToRokKrXIPQSOE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 20,
#               'vicinity': 'Matara'},
#              {'geometry': {'location': {'lat': 5.939464, 'lng': 80.568156},
#                            'viewport': {'northeast': {'lat': 5.940773229892722,
#                                                       'lng': 80.56959712989271},
#                                         'southwest': {'lat': 5.938073570107278,
#                                                       'lng': 80.56689747010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '52a1cb4fe143215de6351d219ebc403e55d2707c',
#               'name': 'Vanina Villas',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 750,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107877976972421820970">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAqjxRSADOv73fTwlz3cKLVhUIWVsSJ63DdLNj83E_Ec5OIzol3g1pugF-JK1_nkNMEIVDsRKW5rL9zUkxquyGURZ6MYAVk-npuJv1LPxGqOqT0gmdOJqNdT_VrVx4MfwlEhBIvKdDyFhwxxQ70EmPgiB_GhTvQ0ueoHqj72MhAuvn-zG9Ir42OQ',
#                           'width': 1000}],
#               'place_id': 'ChIJT0uo0hg54ToRV6O9PsVH6Xo',
#               'plus_code': {'compound_code': 'WHQ9+Q7 Matara, Sri Lanka',
#                             'global_code': '6MQ2WHQ9+Q7'},
#               'rating': 4.7,
#               'reference': 'ChIJT0uo0hg54ToRV6O9PsVH6Xo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 35,
#               'vicinity': '60 Araliya Beach Road, Meddawatta, Matara'},
#              {'geometry': {'location': {'lat': 5.936615499999999,
#                                         'lng': 80.516244},
#                            'viewport': {'northeast': {'lat': 5.937885429892722,
#                                                       'lng': 80.51759147989272},
#                                         'southwest': {'lat': 5.935185770107278,
#                                                       'lng': 80.51489182010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'd43beecfbbaed11eb0d0afe9e5e4ff138760daab',
#               'name': 'Peak Point Place',
#               'photos': [{'height': 4623,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114561430305895387945">I-YOGA '
#                                                 'PRESENTS</a>'],
#                           'photo_reference': 'CmRaAAAAGThCITc7T9NF3A0wMp-41Xtne6phY_pSr8w9jGgLRaeEEMI4TzX8w46pAVUzytDeDm64KTxNd8GYfNRZDv80goZCp9viP7fjVjs_H4Joj3WRpjgWZJRmpmb6JPhIYyryEhDT_OrdtTCozWpa_pXZwOedGhQXEpw95dPn_MazW6sV7F0K85V_bw',
#                           'width': 3460}],
#               'place_id': 'ChIJhS1Hkds-4ToRP_78g1ajkJU',
#               'plus_code': {'compound_code': 'WGP8+JF Matara, Sri Lanka',
#                             'global_code': '6MQ2WGP8+JF'},
#               'rating': 5,
#               'reference': 'ChIJhS1Hkds-4ToRP_78g1ajkJU',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'lodging',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': 'Beach Road 190/5 Madiha'},
#              {'geometry': {'location': {'lat': 5.937323, 'lng': 80.512295},
#                            'viewport': {'northeast': {'lat': 5.938759479892721,
#                                                       'lng': 80.51366557989272},
#                                         'southwest': {'lat': 5.936059820107277,
#                                                       'lng': 80.51096592010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '131225bf1e6c6b903ef890379f2c1dcbee827f65',
#               'name': 'Villa Aviksha',
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112830978775425355935">Tomáš '
#                                                 'Zvelebil</a>'],
#                           'photo_reference': 'CmRaAAAAL5bTh1GYCKBBH7ttwtB7pSrkNVJQjao62apw7H1D7JwnFEYgF242AfZbr9TueM4xaG8h6zwwzVGNUBG7Qq4x1zpe5A8QEchzWGOkHNADnMTzs2Izt2U0jBV0vXnEcrN9EhDqLUasCJBFHWnY7c2VSKPBGhTNegIrJvB0tYH2rnmFiayO0hPQew',
#                           'width': 2240}],
#               'place_id': 'ChIJa9duk-Q-4ToRtTFL_BHA3D0',
#               'plus_code': {'compound_code': 'WGP6+WW Matara, Sri Lanka',
#                             'global_code': '6MQ2WGP6+WW'},
#               'rating': 4.4,
#               'reference': 'ChIJa9duk-Q-4ToRtTFL_BHA3D0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': 'Matara'},
#              {'geometry': {'location': {'lat': 5.9396877, 'lng': 80.5686385},
#                            'viewport': {'northeast': {'lat': 5.940977629892722,
#                                                       'lng': 80.56995457989272},
#                                         'southwest': {'lat': 5.938277970107278,
#                                                       'lng': 80.56725492010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '784d5af2ce9a57b5d1cb0f4863d095542beb6d30',
#               'name': 'Top Secret Beach Hotel',
#               'photos': [{'height': 853,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111352441308060062141">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA1en4qttx0w_9CmGjfBSiGsgTKNy9XqGXhRTLHZroE5ejXFPvwjfOlvrqsQyUroOYwh1tT-zlMKhNIhkwIK1gQs0TN2j5Zi7P33XDAwOaQxmHH2pGU8IRXRSVhwQYl-4AEhA5-0lXid798UQGAgiATFfqGhRJFf2POOjjTBAyiAMHLDFxJvdRqQ',
#                           'width': 1280}],
#               'place_id': 'ChIJvQ_79x454ToRYb5RgD6RAm0',
#               'plus_code': {'compound_code': 'WHQ9+VF Matara, Sri Lanka',
#                             'global_code': '6MQ2WHQ9+VF'},
#               'rating': 4.1,
#               'reference': 'ChIJvQ_79x454ToRYb5RgD6RAm0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'Araliya Beach Rd, Maddawatta'},
#              {'geometry': {'location': {'lat': 5.9362792,
#                                         'lng': 80.51875129999999},
#                            'viewport': {'northeast': {'lat': 5.93756817989272,
#                                                       'lng': 80.52008567989272},
#                                         'southwest': {'lat': 5.934868520107276,
#                                                       'lng': 80.51738602010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '73ba74dd2dc698778a9801b0176226d0db4c1fb1',
#               'name': 'Sea Life Hotel',
#               'photos': [{'height': 713,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110499967497874267541">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAfEkT8x28bPC42NIAuSDqdQZH71jerbBQebmgyiVUNCjJI5g5vDsO_3sUE0h2EyTZa3ZEBhxk_WV7z5OfNG1pXRVnNxgef6PAYI1ujjw49WkOeBPEbau73dZc1y-pbV6aEhC63Zt5bnrB4JfBSzOyPRu8GhS3NliHFylr04I6YF51IRBhXdfKeA',
#                           'width': 1080}],
#               'place_id': 'ChIJcdZq_uY-4ToRdgqfWan61pY',
#               'plus_code': {'compound_code': 'WGP9+GG Matara, Sri Lanka',
#                             'global_code': '6MQ2WGP9+GG'},
#               'rating': 4.8,
#               'reference': 'ChIJcdZq_uY-4ToRdgqfWan61pY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': 'Matara'},
#              {'geometry': {'location': {'lat': 5.9365296, 'lng': 80.5247176},
#                            'viewport': {'northeast': {'lat': 5.937879579892722,
#                                                       'lng': 80.52607862989271},
#                                         'southwest': {'lat': 5.935179920107278,
#                                                       'lng': 80.52337897010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'bd3dfd5ca3ee35f1764cd5080d8cf6b6256c0721',
#               'name': 'SunFlower Villa',
#               'photos': [{'height': 576,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117527746526646855470">patrice '
#                                                 'Lemarie</a>'],
#                           'photo_reference': 'CmRaAAAAO0e-YAS9_NmTkjdCEaxhJcUhasGWlabXl_cFW9DiC8TyT4p1R92vJJR2snNksBpIHcpp0TguTChfEz8g_IQiPQOy1hgBRk6LwRHvXWgOTqk3XWMcxWG8lwPPh3l_dz0JEhCMkoLEoxSAV46F4jxCPQRlGhTwvJvhhMn4VAuhdKeliWQkKHlrlg',
#                           'width': 864}],
#               'place_id': 'ChIJO-M4kds-4ToRJ3_pKmCLipo',
#               'plus_code': {'compound_code': 'WGPF+JV Matara, Sri Lanka',
#                             'global_code': '6MQ2WGPF+JV'},
#               'rating': 4.3,
#               'reference': 'ChIJO-M4kds-4ToRJ3_pKmCLipo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 6,
#               'vicinity': '61 Beach Rd, Matara'},
#              {'geometry': {'location': {'lat': 5.9364789, 'lng': 80.5184512},
#                            'viewport': {'northeast': {'lat': 5.937834179892722,
#                                                       'lng': 80.51972822989273},
#                                         'southwest': {'lat': 5.935134520107278,
#                                                       'lng': 80.51702857010729}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4f4f6fdbdc6360493a7b8c0aee2f981612859e66',
#               'name': 'MY-HOME-RESORT',
#               'place_id': 'ChIJZYGt7YA_4ToRSkHJ8WPbefw',
#               'plus_code': {'compound_code': 'WGP9+H9 Matara, Sri Lanka',
#                             'global_code': '6MQ2WGP9+H9'},
#               'rating': 5,
#               'reference': 'ChIJZYGt7YA_4ToRSkHJ8WPbefw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'Matara'}],
#  'status': 'OK'}

# %%
hotel_names
# set up parameters dict
# for o in range(len(cities)):
    
#     params = {
#         'location': {ideal_weather_df['Lat'],ideal_weather_df['Lng']},
#         'keyword': 'hotel',
#         'radius': 5000,
#         'type': 'hotel',
#         'key': g_key
#     }
# Out:
# ['The LaLiT Golf & Spa Resort Goa',
#  'Hotel Costanera, Valdivia - Centro Turístico Caja los Andes',
#  'Peñasco Del Sol Hotel and Conference Center',
#  'ZERO_RESULTS',
#  'Beach Abode Beachfront Lodge',
#  'The Esplanade Resort & Spa',
#  'HOTEL YAAKUNAH',
#  'La Coral Beach Villa']

# %%
ideal_hotels_dict = {
    'City': ideal_weather_df['City'],
    'Country': hotel_country,
    'Hotel Name': hotel_names,
    'Lat': hotel_lat,
    'Lng': hotel_lng
}
ideal_hotels_df = pd.DataFrame(ideal_hotels_dict)
ideal_hotels_df
# Out:
#              City Country                                         Hotel Name  \
# 0          Kankon      IN                    The LaLiT Golf & Spa Resort Goa
# 1        Valdivia      CL  Hotel Costanera, Valdivia - Centro Turístico C...
# 2  Puerto Penasco      MX        Peñasco Del Sol Hotel and Conference Center
# 3            Sola      VU                                       ZERO_RESULTS
# 4         Ahipara      NZ                       Beach Abode Beachfront Lodge
# 5  Lakes Entrance      AU                         The Esplanade Resort & Spa
# 6       Escarcega      MX                                     HOTEL YAAKUNAH
# 7          Matara      LK                               La Coral Beach Villa
#
#             Lat           Lng
# 0        14.991       74.0402
# 1      -39.8165      -73.2324
# 2       31.3108      -113.548
# 3  ZERO_RESULTS  ZERO_RESULTS
# 4      -35.1627       173.155
# 5      -37.8824       147.974
# 6       18.6088      -90.7287
# 7       5.93818        80.517

# %%
# remove no results
zero_results = ideal_hotels_df[ideal_hotels_df['Hotel Name']=='ZERO_RESULTS'].index
ideal_hotels_df.drop(zero_results, inplace=True)
ideal_hotels_idx_rst = ideal_hotels_df.reset_index(drop=True)
ideal_hotels_idx_rst
# Out:
#              City Country                                         Hotel Name  \
# 0          Kankon      IN                    The LaLiT Golf & Spa Resort Goa
# 1        Valdivia      CL  Hotel Costanera, Valdivia - Centro Turístico C...
# 2  Puerto Penasco      MX        Peñasco Del Sol Hotel and Conference Center
# 3         Ahipara      NZ                       Beach Abode Beachfront Lodge
# 4  Lakes Entrance      AU                         The Esplanade Resort & Spa
# 5       Escarcega      MX                                     HOTEL YAAKUNAH
# 6          Matara      LK                               La Coral Beach Villa
#
#        Lat      Lng
# 0   14.991  74.0402
# 1 -39.8165 -73.2324
# 2  31.3108 -113.548
# 3 -35.1627  173.155
# 4 -37.8824  147.974
# 5  18.6088 -90.7287
# 6  5.93818   80.517

# %%
coordinates = []
# ideal_hotels_df['Lat'][0]
for x in range(len(ideal_hotels_idx_rst)):
    coordinates.append((ideal_hotels_idx_rst['Lat'][x],ideal_hotels_idx_rst['Lng'][x]))
    # print(ideal_hotels_idx_rst['Lat'][x])
coordinates
# Out:
# [(14.991011, 74.04016899999999),
#  (-39.8165377, -73.2324385),
#  (31.310767, -113.54804),
#  (-35.1626808, 173.1549275),
#  (-37.8824387, 147.9743885),
#  (18.6087818, -90.72870340000001),
#  (5.938178499999999, 80.51696319999999)]

# %%
# hotel details: hotel name, city, country
hotel_details = []
for detail in range(len(ideal_hotels_idx_rst)):
    hotel_details.append(f"<strong>Hotel Name:</strong><br>{ideal_hotels_idx_rst['Hotel Name'][detail]}<br><br>\
                         <strong>City:</strong><br>{ideal_hotels_idx_rst['City'][detail]}<br><br>\
                         <strong>Country:</strong><br>{ideal_hotels_idx_rst['Country'][detail]}")
    
print(hotel_details)    
# assign marker layer to a variable
hotel_markers = gmaps.marker_layer(coordinates,info_box_content=hotel_details)
# add the layer to map
fig.add_layer(hotel_markers)
fig
# Out:
# ['<strong>Hotel Name:</strong><br>The LaLiT Golf & Spa Resort Goa<br><br>                         <strong>City:</strong><br>Kankon<br><br>                         <strong>Country:</strong><br>IN', '<strong>Hotel Name:</strong><br>Hotel Costanera, Valdivia - Centro Turístico Caja los Andes<br><br>                         <strong>City:</strong><br>Valdivia<br><br>                         <strong>Country:</strong><br>CL', '<strong>Hotel Name:</strong><br>Peñasco Del Sol Hotel and Conference Center<br><br>                         <strong>City:</strong><br>Puerto Penasco<br><br>                         <strong>Country:</strong><br>MX', '<strong>Hotel Name:</strong><br>Beach Abode Beachfront Lodge<br><br>                         <strong>City:</strong><br>Ahipara<br><br>                         <strong>Country:</strong><br>NZ', '<strong>Hotel Name:</strong><br>The Esplanade Resort & Spa<br><br>                         <strong>City:</strong><br>Lakes Entrance<br><br>                         <strong>Country:</strong><br>AU', '<strong>Hotel Name:</strong><br>HOTEL YAAKUNAH<br><br>                         <strong>City:</strong><br>Escarcega<br><br>                         <strong>Country:</strong><br>MX', '<strong>Hotel Name:</strong><br>La Coral Beach Villa<br><br>                         <strong>City:</strong><br>Matara<br><br>                         <strong>Country:</strong><br>LK']
# Figure(layout=FigureLayout(height='420px'))
